# %% [markdown]
# # Sort a DataFrame with the sort_values Method I

# %%
import pandas as pd

# %%
nba = pd.read_csv('nba.csv')
nba.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
nba.dropna(how='all')
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
nba = pd.read_csv('nba.csv')
nba.head(n=2)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
#
#      College     Salary
# 0      Texas  7730337.0
# 1  Marquette  6796117.0

# %%
nba['Name']
# Out:
# 0      Avery Bradley
# 1        Jae Crowder
# 2       John Holland
# 3        R.J. Hunter
# 4      Jonas Jerebko
#            ...
# 453     Shelvin Mack
# 454        Raul Neto
# 455     Tibor Pleiss
# 456      Jeff Withey
# 457              NaN
# Name: Name, Length: 458, dtype: object

# %%
nba['Name'].sort_values()
# Out:
# 152      Aaron Brooks
# 356      Aaron Gordon
# 328    Aaron Harrison
# 404     Adreian Payne
# 312        Al Horford
#             ...
# 270    Xavier Munford
# 402       Zach LaVine
# 271     Zach Randolph
# 237     Zaza Pachulia
# 457               NaN
# Name: Name, Length: 458, dtype: object

# %%
nba['Salary']
# Out:
# 0      7730337.0
# 1      6796117.0
# 2            NaN
# 3      1148640.0
# 4      5000000.0
#          ...
# 453    2433333.0
# 454     900000.0
# 455    2900000.0
# 456     947276.0
# 457          NaN
# Name: Salary, Length: 458, dtype: float64

# %%
nba['Salary'].sort_values()
# Out:
# 32      30888.0
# 291     55722.0
# 130     55722.0
# 135     83397.0
# 175    111196.0
#          ...
# 350         NaN
# 353         NaN
# 397         NaN
# 409         NaN
# 457         NaN
# Name: Salary, Length: 458, dtype: float64

# %%
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
nba.sort_values(by='Name')
# Out:
#                Name                    Team  Number Position   Age Height  \
# 152    Aaron Brooks           Chicago Bulls     0.0       PG  31.0    6-0
# 356    Aaron Gordon           Orlando Magic     0.0       PF  20.0    6-9
# 328  Aaron Harrison       Charlotte Hornets     9.0       SG  21.0    6-6
# 404   Adreian Payne  Minnesota Timberwolves    33.0       PF  25.0   6-10
# 312      Al Horford           Atlanta Hawks    15.0        C  30.0   6-10
# ..              ...                     ...     ...      ...   ...    ...
# 270  Xavier Munford       Memphis Grizzlies    14.0       PG  24.0    6-3
# 402     Zach LaVine  Minnesota Timberwolves     8.0       PG  21.0    6-5
# 271   Zach Randolph       Memphis Grizzlies    50.0       PF  34.0    6-9
# 237   Zaza Pachulia        Dallas Mavericks    27.0        C  32.0   6-11
# 457             NaN                     NaN     NaN      NaN   NaN    NaN
#
#      Weight         College      Salary
# ...

# %%
nba.sort_values(by='Name', ascending=False)
# Out:
#                 Name                    Team  Number Position   Age Height  \
# 237    Zaza Pachulia        Dallas Mavericks    27.0        C  32.0   6-11
# 271    Zach Randolph       Memphis Grizzlies    50.0       PF  34.0    6-9
# 402      Zach LaVine  Minnesota Timberwolves     8.0       PG  21.0    6-5
# 270   Xavier Munford       Memphis Grizzlies    14.0       PG  24.0    6-3
# 386  Wilson Chandler          Denver Nuggets    21.0       SF  29.0    6-8
# ..               ...                     ...     ...      ...   ...    ...
# 404    Adreian Payne  Minnesota Timberwolves    33.0       PF  25.0   6-10
# 328   Aaron Harrison       Charlotte Hornets     9.0       SG  21.0    6-6
# 356     Aaron Gordon           Orlando Magic     0.0       PF  20.0    6-9
# 152     Aaron Brooks           Chicago Bulls     0.0       PG  31.0    6-0
# 457              NaN                     NaN     NaN      NaN   NaN    NaN
#
#      Weight         College      Salary
# ...

# %%
nba.sort_values(by='Age',ascending=False).head(n=7)
# Out:
#                Name                    Team  Number Position   Age Height  \
# 304    Andre Miller       San Antonio Spurs    24.0       PG  40.0    6-3
# 400   Kevin Garnett  Minnesota Timberwolves    21.0       PF  40.0   6-11
# 298      Tim Duncan       San Antonio Spurs    21.0        C  40.0   6-11
# 261    Vince Carter       Memphis Grizzlies    15.0       SG  39.0    6-6
# 102  Pablo Prigioni    Los Angeles Clippers     9.0       PG  39.0    6-3
# 299   Manu Ginobili       San Antonio Spurs    20.0       SG  38.0    6-6
# 101     Paul Pierce    Los Angeles Clippers    34.0       SF  38.0    6-7
#
#      Weight         College     Salary
# 304   200.0            Utah   250750.0
# 400   240.0             NaN  8500000.0
# 298   250.0     Wake Forest  5250000.0
# 261   220.0  North Carolina  4088019.0
# 102   185.0             NaN   947726.0
# 299   205.0             NaN  2814000.0
# 101   235.0          Kansas  3376000.0

# %%
nba.sort_values('Salary')
# Out:
#                        Name                    Team  Number Position   Age  \
# 32   Thanasis Antetokounmpo         New York Knicks    43.0       SF  23.0
# 291         Orlando Johnson    New Orleans Pelicans     0.0       SG  27.0
# 130            Phil Pressey            Phoenix Suns    25.0       PG  25.0
# 135           Alan Williams            Phoenix Suns    15.0        C  23.0
# 175            Jordan McRae     Cleveland Cavaliers    12.0       SG  25.0
# ..                      ...                     ...     ...      ...   ...
# 350           Briante Weber              Miami Heat    12.0       PG  23.0
# 353           Dorell Wright              Miami Heat    11.0       SF  30.0
# 397            Axel Toupane          Denver Nuggets     6.0       SG  23.0
# 409              Greg Smith  Minnesota Timberwolves     4.0       PF  25.0
# 457                     NaN                     NaN     NaN      NaN   NaN
#
#     Height  Weight                College    Salary
# ...

# %%
nba.sort_values('Salary', na_position= 'first')
# Out:
#                 Name                 Team  Number Position   Age Height  \
# 2       John Holland       Boston Celtics    30.0       SG  27.0    6-5
# 46       Elton Brand   Philadelphia 76ers    42.0       PF  37.0    6-9
# 171    Dahntay Jones  Cleveland Cavaliers    30.0       SG  35.0    6-6
# 264    Jordan Farmar    Memphis Grizzlies     4.0       PG  29.0    6-2
# 269     Ray McCallum    Memphis Grizzlies     5.0       PG  24.0    6-3
# ..               ...                  ...     ...      ...   ...    ...
# 339       Chris Bosh           Miami Heat     1.0       PF  32.0   6-11
# 251    Dwight Howard      Houston Rockets    12.0        C  30.0   6-11
# 33   Carmelo Anthony      New York Knicks     7.0       SF  32.0    6-8
# 169     LeBron James  Cleveland Cavaliers    23.0       SF  31.0    6-8
# 109      Kobe Bryant   Los Angeles Lakers    24.0       SF  37.0    6-6
#
#      Weight            College      Salary
# 2     205.0  Boston University         NaN
# ...

# %%
nba.sort_values('Salary', na_position='first', ascending=False)
# Out:
#                        Name                  Team  Number Position   Age  \
# 2              John Holland        Boston Celtics    30.0       SG  27.0
# 46              Elton Brand    Philadelphia 76ers    42.0       PF  37.0
# 171           Dahntay Jones   Cleveland Cavaliers    30.0       SG  35.0
# 264           Jordan Farmar     Memphis Grizzlies     4.0       PG  29.0
# 269            Ray McCallum     Memphis Grizzlies     5.0       PG  24.0
# ..                      ...                   ...     ...      ...   ...
# 175            Jordan McRae   Cleveland Cavaliers    12.0       SG  25.0
# 135           Alan Williams          Phoenix Suns    15.0        C  23.0
# 291         Orlando Johnson  New Orleans Pelicans     0.0       SG  27.0
# 130            Phil Pressey          Phoenix Suns    25.0       PG  25.0
# 32   Thanasis Antetokounmpo       New York Knicks    43.0       SF  23.0
#
#     Height  Weight            College    Salary
# ...

# %%
nba.sort_values('Salary', na_position='last',ascending=False)
# Out:
#                 Name                    Team  Number Position   Age Height  \
# 109      Kobe Bryant      Los Angeles Lakers    24.0       SF  37.0    6-6
# 169     LeBron James     Cleveland Cavaliers    23.0       SF  31.0    6-8
# 33   Carmelo Anthony         New York Knicks     7.0       SF  32.0    6-8
# 251    Dwight Howard         Houston Rockets    12.0        C  30.0   6-11
# 339       Chris Bosh              Miami Heat     1.0       PF  32.0   6-11
# ..               ...                     ...     ...      ...   ...    ...
# 350    Briante Weber              Miami Heat    12.0       PG  23.0    6-2
# 353    Dorell Wright              Miami Heat    11.0       SF  30.0    6-9
# 397     Axel Toupane          Denver Nuggets     6.0       SG  23.0    6-7
# 409       Greg Smith  Minnesota Timberwolves     4.0       PF  25.0   6-10
# 457              NaN                     NaN     NaN      NaN   NaN    NaN
#
#      Weight                College      Salary
# ...

# %%
nba.sort_values(by='Team', na_position='first')
# Out:
#                  Name                Team  Number Position   Age Height  \
# 457               NaN                 NaN     NaN      NaN   NaN    NaN
# 317   Lamar Patterson       Atlanta Hawks    13.0       SG  24.0    6-5
# 309     Kent Bazemore       Atlanta Hawks    24.0       SF  26.0    6-5
# 310  Tim Hardaway Jr.       Atlanta Hawks    10.0       SG  24.0    6-6
# 311      Kirk Hinrich       Atlanta Hawks    12.0       SG  35.0    6-4
# ..                ...                 ...     ...      ...   ...    ...
# 371      Jarell Eddie  Washington Wizards     8.0       SG  24.0    6-7
# 369      Bradley Beal  Washington Wizards     3.0       SG  22.0    6-5
# 368     Alan Anderson  Washington Wizards     6.0       SG  33.0    6-6
# 382         John Wall  Washington Wizards     2.0       PG  25.0    6-4
# 370      Jared Dudley  Washington Wizards     1.0       SF  30.0    6-7
#
#      Weight         College      Salary
# 457     NaN             NaN         NaN
# ...

# %%
nba.sort_values(by='Name', ascending=False).head(n=8)
# Out:
#                     Name                    Team  Number Position   Age  \
# 237        Zaza Pachulia        Dallas Mavericks    27.0        C  32.0
# 271        Zach Randolph       Memphis Grizzlies    50.0       PF  34.0
# 402          Zach LaVine  Minnesota Timberwolves     8.0       PG  21.0
# 270       Xavier Munford       Memphis Grizzlies    14.0       PG  24.0
# 386      Wilson Chandler          Denver Nuggets    21.0       SF  29.0
# 25           Willie Reed           Brooklyn Nets    33.0       PF  26.0
# 141  Willie Cauley-Stein        Sacramento Kings     0.0        C  22.0
# 385          Will Barton          Denver Nuggets     5.0       SF  25.0
#
#     Height  Weight         College      Salary
# 237   6-11   275.0             NaN   5200000.0
# 271    6-9   260.0  Michigan State   9638555.0
# 402    6-5   189.0            UCLA   2148360.0
# 270    6-3   180.0    Rhode Island         NaN
# 386    6-8   225.0          DePaul  10449438.0
# ...

# %%
nba = nba.sort_values(by='Name', ascending=False)

# %%
nba.head(n=9)
# Out:
#                     Name                    Team  Number Position   Age  \
# 237        Zaza Pachulia        Dallas Mavericks    27.0        C  32.0
# 271        Zach Randolph       Memphis Grizzlies    50.0       PF  34.0
# 402          Zach LaVine  Minnesota Timberwolves     8.0       PG  21.0
# 270       Xavier Munford       Memphis Grizzlies    14.0       PG  24.0
# 386      Wilson Chandler          Denver Nuggets    21.0       SF  29.0
# 25           Willie Reed           Brooklyn Nets    33.0       PF  26.0
# 141  Willie Cauley-Stein        Sacramento Kings     0.0        C  22.0
# 385          Will Barton          Denver Nuggets     5.0       SF  25.0
# 233      Wesley Matthews        Dallas Mavericks    23.0       SG  29.0
#
#     Height  Weight         College      Salary
# 237   6-11   275.0             NaN   5200000.0
# 271    6-9   260.0  Michigan State   9638555.0
# 402    6-5   189.0            UCLA   2148360.0
# 270    6-3   180.0    Rhode Island         NaN
# ...

# %% [markdown]
# # Sort DataFrame with the sort_values Method II

# %%
nba = pd.read_csv('nba.csv').dropna(how='all')

# %%
nba.sort_values(by='Salary', na_position='first').head(n=9)
# Out:
#                Name                 Team  Number Position   Age Height  \
# 2      John Holland       Boston Celtics    30.0       SG  27.0    6-5
# 46      Elton Brand   Philadelphia 76ers    42.0       PF  37.0    6-9
# 171   Dahntay Jones  Cleveland Cavaliers    30.0       SG  35.0    6-6
# 264   Jordan Farmar    Memphis Grizzlies     4.0       PG  29.0    6-2
# 269    Ray McCallum    Memphis Grizzlies     5.0       PG  24.0    6-3
# 270  Xavier Munford    Memphis Grizzlies    14.0       PG  24.0    6-3
# 273  Alex Stepheson    Memphis Grizzlies    35.0       PF  28.0   6-10
# 350   Briante Weber           Miami Heat    12.0       PG  23.0    6-2
# 353   Dorell Wright           Miami Heat    11.0       SF  30.0    6-9
#
#      Weight                College  Salary
# 2     205.0      Boston University     NaN
# 46    254.0                   Duke     NaN
# 171   225.0                   Duke     NaN
# 264   180.0                   UCLA     NaN
# ...

# %%
nba.sort_values(by=['Team', 'Name']).head(n=11)
# Out:
#                 Name           Team  Number Position   Age Height  Weight  \
# 312       Al Horford  Atlanta Hawks    15.0        C  30.0   6-10   245.0
# 318  Dennis Schroder  Atlanta Hawks    17.0       PG  22.0    6-1   172.0
# 323      Jeff Teague  Atlanta Hawks     0.0       PG  27.0    6-2   186.0
# 309    Kent Bazemore  Atlanta Hawks    24.0       SF  26.0    6-5   201.0
# 311     Kirk Hinrich  Atlanta Hawks    12.0       SG  35.0    6-4   190.0
# 313   Kris Humphries  Atlanta Hawks    43.0       PF  31.0    6-9   235.0
# 314      Kyle Korver  Atlanta Hawks    26.0       SG  35.0    6-7   212.0
# 317  Lamar Patterson  Atlanta Hawks    13.0       SG  24.0    6-5   225.0
# 316     Mike Muscala  Atlanta Hawks    31.0       PF  24.0   6-11   240.0
# 319       Mike Scott  Atlanta Hawks    32.0       PF  27.0    6-8   237.0
# 315     Paul Millsap  Atlanta Hawks     4.0       PF  31.0    6-8   246.0
#
#             College      Salary
# 312         Florida  12000000.0
# ...

# %%
nba.sort_values(by=['Team', 'Name'], ascending=[False,False])
# Out:
#                 Name                Team  Number Position   Age Height  \
# 379   Ramon Sessions  Washington Wizards     7.0       PG  30.0    6-3
# 378  Otto Porter Jr.  Washington Wizards    22.0       SF  23.0    6-8
# 375     Nene Hilario  Washington Wizards    42.0        C  33.0   6-11
# 376  Markieff Morris  Washington Wizards     5.0       PF  26.0   6-10
# 381  Marcus Thornton  Washington Wizards    15.0       SF  29.0    6-4
# ..               ...                 ...     ...      ...   ...    ...
# 311     Kirk Hinrich       Atlanta Hawks    12.0       SG  35.0    6-4
# 309    Kent Bazemore       Atlanta Hawks    24.0       SF  26.0    6-5
# 323      Jeff Teague       Atlanta Hawks     0.0       PG  27.0    6-2
# 318  Dennis Schroder       Atlanta Hawks    17.0       PG  22.0    6-1
# 312       Al Horford       Atlanta Hawks    15.0        C  30.0   6-10
#
#      Weight       College      Salary
# 379   190.0        Nevada   2170465.0
# ...

# %%
column_list = ['Team','Name']
sort_order = [False, True]
nba.sort_values(by=column_list, ascending=sort_order)
# Out:
#                  Name                Team  Number Position   Age Height  \
# 368     Alan Anderson  Washington Wizards     6.0       SG  33.0    6-6
# 369      Bradley Beal  Washington Wizards     3.0       SG  22.0    6-5
# 372       Drew Gooden  Washington Wizards    90.0       PF  34.0   6-10
# 380    Garrett Temple  Washington Wizards    17.0       SG  30.0    6-6
# 374        JJ Hickson  Washington Wizards    21.0        C  27.0    6-9
# ..                ...                 ...     ...      ...   ...    ...
# 315      Paul Millsap       Atlanta Hawks     4.0       PF  31.0    6-8
# 320   Thabo Sefolosha       Atlanta Hawks    25.0       SF  32.0    6-7
# 321    Tiago Splitter       Atlanta Hawks    11.0        C  31.0   6-11
# 310  Tim Hardaway Jr.       Atlanta Hawks    10.0       SG  24.0    6-6
# 322    Walter Tavares       Atlanta Hawks    22.0        C  24.0    7-3
#
#      Weight               College      Salary
# 368   220.0        Michigan State   4000000.0
# ...

# %%
column_list = ['Position', 'Salary']
nba.sort_values(by=column_list, ascending=sort_order)
# Out:
#                    Name                   Team  Number Position   Age Height  \
# 291     Orlando Johnson   New Orleans Pelicans     0.0       SG  27.0    6-5
# 175        Jordan McRae    Cleveland Cavaliers    12.0       SG  25.0    6-5
# 21      Sean Kilpatrick          Brooklyn Nets     6.0       SG  26.0    6-4
# 45          Tony Wroten        New York Knicks     5.0       SG  23.0    6-6
# 282  Bryce Dejean-Jones   New Orleans Pelicans    31.0       SG  23.0    6-6
# ..                  ...                    ...     ...      ...   ...    ...
# 418         Enes Kanter  Oklahoma City Thunder    11.0        C  24.0   6-11
# 265          Marc Gasol      Memphis Grizzlies    33.0        C  31.0    7-1
# 23          Brook Lopez          Brooklyn Nets    11.0        C  28.0    7-0
# 98       DeAndre Jordan   Los Angeles Clippers     6.0        C  27.0   6-11
# 251       Dwight Howard        Houston Rockets    12.0        C  30.0   6-11
#
#      Weight           College      Salary
# ...

# %%
nba.sort_values(by=column_list, ascending=[True,False])
# Out:
#                 Name                  Team  Number Position   Age Height  \
# 251    Dwight Howard       Houston Rockets    12.0        C  30.0   6-11
# 23       Brook Lopez         Brooklyn Nets    11.0        C  28.0    7-0
# 98    DeAndre Jordan  Los Angeles Clippers     6.0        C  27.0   6-11
# 265       Marc Gasol     Memphis Grizzlies    33.0        C  31.0    7-1
# 220      Greg Monroe       Milwaukee Bucks    15.0        C  26.0   6-11
# ..               ...                   ...     ...      ...   ...    ...
# 175     Jordan McRae   Cleveland Cavaliers    12.0       SG  25.0    6-5
# 291  Orlando Johnson  New Orleans Pelicans     0.0       SG  27.0    6-5
# 2       John Holland        Boston Celtics    30.0       SG  27.0    6-5
# 171    Dahntay Jones   Cleveland Cavaliers    30.0       SG  35.0    6-6
# 397     Axel Toupane        Denver Nuggets     6.0       SG  23.0    6-7
#
#      Weight            College      Salary
# 251   265.0                NaN  22359364.0
# ...

# %%
nba.head(n=2)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
#
#      College     Salary
# 0      Texas  7730337.0
# 1  Marquette  6796117.0

# %%
for column in nba.columns:
    print(column)
# Out:
# Name
# Team
# Number
# Position
# Age
# Height
# Weight
# College
# Salary

# %%
nba_unique_values =  nba['Team'].value_counts().index
type(nba_unique_values)
# Out:
# pandas.core.indexes.base.Index

# %%
nba_unique_values
# Out:
# Index(['New Orleans Pelicans', 'Memphis Grizzlies', 'New York Knicks',
#        'Milwaukee Bucks', 'Boston Celtics', 'Brooklyn Nets',
#        'Portland Trail Blazers', 'Oklahoma City Thunder', 'Denver Nuggets',
#        'Washington Wizards', 'Miami Heat', 'Charlotte Hornets',
#        'Atlanta Hawks', 'San Antonio Spurs', 'Houston Rockets',
#        'Dallas Mavericks', 'Indiana Pacers', 'Detroit Pistons',
#        'Cleveland Cavaliers', 'Chicago Bulls', 'Sacramento Kings',
#        'Phoenix Suns', 'Los Angeles Lakers', 'Los Angeles Clippers',
#        'Golden State Warriors', 'Toronto Raptors', 'Philadelphia 76ers',
#        'Utah Jazz', 'Orlando Magic', 'Minnesota Timberwolves'],
#       dtype='object')

# %%
list_nba = []
for i in nba_unique_values:
    list_nba.append(i)

# %%
len(list_nba)
# Out:
# 30

# %%
nba_teams = nba['Team'].value_counts()
type(nba_teams)
# Out:
# pandas.core.series.Series

# %%
nba_teams_unique = nba_teams.unique()
nba_teams_unique
# Out:
# array([19, 18, 16, 15, 14], dtype=int64)

# %%
for i in nba_teams_unique:
    print(i)
# Out:
# 19
# 18
# 16
# 15
# 14

# %%
nba['Team'].value_counts(sort=False)
# Out:
# Boston Celtics            15
# Brooklyn Nets             15
# New York Knicks           16
# Philadelphia 76ers        15
# Toronto Raptors           15
# Golden State Warriors     15
# Los Angeles Clippers      15
# Los Angeles Lakers        15
# Phoenix Suns              15
# Sacramento Kings          15
# Chicago Bulls             15
# Cleveland Cavaliers       15
# Detroit Pistons           15
# Indiana Pacers            15
# Milwaukee Bucks           16
# Dallas Mavericks          15
# Houston Rockets           15
# Memphis Grizzlies         18
# New Orleans Pelicans      19
# San Antonio Spurs         15
# Atlanta Hawks             15
# Charlotte Hornets         15
# Miami Heat                15
# Orlando Magic             14
# Washington Wizards        15
# Denver Nuggets            15
# Minnesota Timberwolves    14
# Oklahoma City Thunder     15
# Portland Trail Blazers    15
# Utah Jazz                 15
# Name: Team, dtype: int64

# %%
nba['Name'].value_counts(sort=False)
# Out:
# Avery Bradley    1
# Jae Crowder      1
# John Holland     1
# R.J. Hunter      1
# Jonas Jerebko    1
#                 ..
# Trey Lyles       1
# Shelvin Mack     1
# Raul Neto        1
# Tibor Pleiss     1
# Jeff Withey      1
# Name: Name, Length: 457, dtype: int64

# %%
column_list = ['Name', 'Team', 'Number','Position']

# %%
nba.head(n=2)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
#
#      College     Salary
# 0      Texas  7730337.0
# 1  Marquette  6796117.0

# %%
nba['Team'].count()
# Out:
# 457

# %%
nba['Team'].value_counts().count()
# Out:
# 30

# %%
for column in nba.columns:
    print(nba[column].value_counts().count())
# Out:
# 457
# 30
# 53
# 5
# 22
# 18
# 87
# 118
# 309

# %%
bigest_value = 0
for value in nba.count().values:
    if value > bigest_value:
        bigest_value = value

bigest_value
# Out:
# 457

# %%
total_rows
# Out:
# array([457, 457, 457, 457, 457, 457, 457, 373, 446], dtype=int64)

# %%
how_unique_nba_is = pd.DataFrame(columns=['Column Name', 'Unique Values'])

# %%
if how_unique_nba_is.index.max() == "nan":
    print("nan")

# %%
how_unique_nba_is.loc[0] = ["Nan","Nan"]

for column in nba.columns:
    # print(round((nba[column].value_counts().count()/bigest_value)*100,2))
    how_unique_nba_is.loc[how_unique_nba_is.index.max() + 1] = [column , round((nba[column].value_counts().count()/bigest_value)*100,2)]

how_unique_nba_is.drop(0)
# Out:
#   Column Name Unique Values
# 1        Name         100.0
# 2        Team          6.56
# 3      Number          11.6
# 4    Position          1.09
# 5         Age          4.81
# 6      Height          3.94
# 7      Weight         19.04
# 8     College         25.82
# 9      Salary         67.61

# %%
how_unique_nba_is.index.max()
# Out:
# 9

# %%
for i in how_unique_nba_is.index:
    how_unique_nba_is.drop(i)

# %%
how_unique_nba_is.head(n=2)
# Out:
#   Column Name Unique Values
# 0         Nan           Nan
# 1        Name         100.0

# %%
how_unique_nba_is.drop(0)
# Out:
#   Column Name Unique Values
# 1        Name         100.0
# 2        Team          6.56
# 3      Number          11.6
# 4    Position          1.09
# 5         Age          4.81
# 6      Height          3.94
# 7      Weight         19.04
# 8     College         25.82
# 9      Salary         67.61

# %%
how_unique_nba_is = None

# %%
how_unique_nba_is
