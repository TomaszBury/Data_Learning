# %% [markdown]
# # Grouping by Multiple Columns

# %%
import pandas as pd

# %%
fortune =pd.read_csv('fortune1000.csv', index_col='Rank')
sectors = fortune.groupby('Sector')
fortune.head(n=2)
# Out:
#           Company     Sector               Industry         Location  Revenue  \
# Rank
# 1         Walmart  Retailing  General Merchandisers  Bentonville, AR   482130
# 2     Exxon Mobil     Energy     Petroleum Refining       Irving, TX   246204
#
#       Profits  Employees
# Rank
# 1       14694    2300000
# 2       16150      75600

# %%
sectors = fortune.groupby(['Sector', 'Industry'])

# %%
sectors.size()
# Out:
# Sector               Industry
# Aerospace & Defense  Aerospace and Defense                            20
# Apparel              Apparel                                          15
# Business Services    Advertising, marketing                            2
#                      Diversified Outsourcing Services                 14
#                      Education                                         3
#                                                                       ..
# Transportation       Trucking, Truck Leasing                           9
# Wholesalers          Miscellaneous                                     1
#                      Wholesalers: Diversified                         25
#                      Wholesalers: Electronics and Office Equipment     8
#                      Wholesalers: Food and Grocery                     6
# Length: 79, dtype: int64

# %%
sectors.get_group('Energy')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Tom\iCloudDrive\Nauka\Python\Pyton_files\Data-Analysis-with-Pandas-and-Python\section_09\158.ipynb Cell 6 in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Tom/iCloudDrive/Nauka/Python/Pyton_files/Data-Analysis-with-Pandas-and-Python/section_09/158.ipynb#ch0000005?line=0'>1</a> sectors.get_group('Energy')
#
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:745, in BaseGroupBy.get_group(self, name, obj)
#     742 if obj is None:
#     743     obj = self._selected_obj
# --> 745 inds = self._get_index(name)
#     746 if not len(inds):
#     747     raise KeyError(name)
#
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:673, in BaseGroupBy._get_index(self, name)
#     668 @final
#     669 def _get_index(self, name):
#     670     """
#     671     Safe get index, translate keys for datelike to underlying repr.
#     672     """
# --> 673     return self._get_indices([name])[0]
#
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:646, in BaseGroupBy._get_indices(self, names)
#     644 if not isinstance(name_sample, tuple):
#     645     msg = "must supply a tuple to get_group with multiple grouping keys"
# --> 646     raise ValueError(msg)
#     647 if not len(name_sample) == len(index_sample):
#     648     try:
#     649         # If the original grouper was a tuple
#
# ValueError: must supply a tuple to get_group with multiple grouping keys

# %%
sectors.sum()
# Out:
#                                                                    Revenue  \
# Sector              Industry
# Aerospace & Defense Aerospace and Defense                           357940
# Apparel             Apparel                                          95968
# Business Services   Advertising, marketing                           22748
#                     Diversified Outsourcing Services                 64829
#                     Education                                         7485
# ...                                                                    ...
# Transportation      Trucking, Truck Leasing                          35950
# Wholesalers         Miscellaneous                                     8982
#                     Wholesalers: Diversified                        176138
#                     Wholesalers: Electronics and Office Equipment   147906
#                     Wholesalers: Food and Grocery                   111774
#
#                                                                    Profits  \
# Sector              Industry
# Aerospace & Defense Aerospace and Defense                            28742
# Apparel             Apparel                                           8236
# Business Services   Advertising, marketing                            1549
#                     Diversified Outsourcing Services                  4305
#                     Education                                           69
# ...                                                                    ...
# Transportation      Trucking, Truck Leasing                           1910
# Wholesalers         Miscellaneous                                       17
#                     Wholesalers: Diversified                          5193
#                     Wholesalers: Electronics and Office Equipment     1857
#                     Wholesalers: Food and Grocery                     1166
#
#                                                                    Employees
# Sector              Industry
# Aerospace & Defense Aerospace and Defense                             968057
# Apparel             Apparel                                           346397
# Business Services   Advertising, marketing                            124100
#                     Diversified Outsourcing Services                  708330
#                     Education                                          46755
# ...                                                                      ...
# Transportation      Trucking, Truck Leasing                           170456
# Wholesalers         Miscellaneous                                       9200
#                     Wholesalers: Diversified                          233831
#                     Wholesalers: Electronics and Office Equipment     166661
#                     Wholesalers: Food and Grocery                     115905
#
# [79 rows x 3 columns]

# %%
sectors.get_group(['Enegry', None])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Tom\iCloudDrive\Nauka\Python\Pyton_files\Data-Analysis-with-Pandas-and-Python\section_09\158.ipynb Cell 8 in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Tom/iCloudDrive/Nauka/Python/Pyton_files/Data-Analysis-with-Pandas-and-Python/section_09/158.ipynb#ch0000007?line=0'>1</a> sectors.get_group(['Enegry', None])
#
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:745, in BaseGroupBy.get_group(self, name, obj)
#     742 if obj is None:
#     743     obj = self._selected_obj
# --> 745 inds = self._get_index(name)
#     746 if not len(inds):
#     747     raise KeyError(name)
#
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:673, in BaseGroupBy._get_index(self, name)
#     668 @final
#     669 def _get_index(self, name):
#     670     """
#     671     Safe get index, translate keys for datelike to underlying repr.
#     672     """
# --> 673     return self._get_indices([name])[0]
#
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:646, in BaseGroupBy._get_indices(self, names)
#     644 if not isinstance(name_sample, tuple):
#     645     msg = "must supply a tuple to get_group with multiple grouping keys"
# --> 646     raise ValueError(msg)
#     647 if not len(name_sample) == len(index_sample):
#     648     try:
#     649         # If the original grouper was a tuple
#
# ValueError: must supply a tuple to get_group with multiple grouping keys

# %%
sectors['Revenue'].sum()
# Out:
# Sector               Industry
# Aerospace & Defense  Aerospace and Defense                            357940
# Apparel              Apparel                                           95968
# Business Services    Advertising, marketing                            22748
#                      Diversified Outsourcing Services                  64829
#                      Education                                          7485
#                                                                        ...
# Transportation       Trucking, Truck Leasing                           35950
# Wholesalers          Miscellaneous                                      8982
#                      Wholesalers: Diversified                         176138
#                      Wholesalers: Electronics and Office Equipment    147906
#                      Wholesalers: Food and Grocery                    111774
# Name: Revenue, Length: 79, dtype: int64

# %%
sectors.get_group('Energy',None)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Tom\iCloudDrive\Nauka\Python\Pyton_files\Data-Analysis-with-Pandas-and-Python\section_09\158.ipynb Cell 10 in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Tom/iCloudDrive/Nauka/Python/Pyton_files/Data-Analysis-with-Pandas-and-Python/section_09/158.ipynb#ch0000009?line=0'>1</a> sectors.get_group('Energy',None)
#
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:745, in BaseGroupBy.get_group(self, name, obj)
#     742 if obj is None:
#     743     obj = self._selected_obj
# --> 745 inds = self._get_index(name)
#     746 if not len(inds):
#     747     raise KeyError(name)
#
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:673, in BaseGroupBy._get_index(self, name)
#     668 @final
#     669 def _get_index(self, name):
#     670     """
#     671     Safe get index, translate keys for datelike to underlying repr.
#     672     """
# --> 673     return self._get_indices([name])[0]
#
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:646, in BaseGroupBy._get_indices(self, names)
#     644 if not isinstance(name_sample, tuple):
#     645     msg = "must supply a tuple to get_group with multiple grouping keys"
# --> 646     raise ValueError(msg)
#     647 if not len(name_sample) == len(index_sample):
#     648     try:
#     649         # If the original grouper was a tuple
#
# ValueError: must supply a tuple to get_group with multiple grouping keys

# %%
sectors.get_group(('Energy', 'Petroleum Refining'))
# Out:
#                                   Company  Sector            Industry  \
# Rank
# 2                             Exxon Mobil  Energy  Petroleum Refining
# 14                                Chevron  Energy  Petroleum Refining
# 30                            Phillips 66  Energy  Petroleum Refining
# 32                          Valero Energy  Energy  Petroleum Refining
# 42                     Marathon Petroleum  Energy  Petroleum Refining
# 98                                 Tesoro  Energy  Petroleum Refining
# 214                         HollyFrontier  Energy  Petroleum Refining
# 217                            PBF Energy  Energy  Petroleum Refining
# 289                      Western Refining  Energy  Petroleum Refining
# 394                                  Hess  Energy  Petroleum Refining
# 445                     Delek US Holdings  Energy  Petroleum Refining
# 569                       Alon USA Energy  Energy  Petroleum Refining
# 571   Calumet Specialty Products Partners  Energy  Petroleum Refining
# 732                  Northern Tier Energy  Energy  Petroleum Refining
# 850                       United Refining  Energy  Petroleum Refining
# 953                  Par Pacific Holdings  Energy  Petroleum Refining
# 983              Adams Resources & Energy  Energy  Petroleum Refining
#
#               Location  Revenue  Profits  Employees
# Rank
# 2           Irving, TX   246204    16150      75600
# 14       San Ramon, CA   131118     4587      61500
# 30         Houston, TX    87169     4227      14000
# 32     San Antonio, TX    81824     3990      10103
# 42         Findlay, OH    64566     2852      45440
# 98     San Antonio, TX    28150     1540       6016
# 214         Dallas, TX    13238      740       2704
# 217     Parsippany, NJ    13124      146       2270
# 289        El Paso, TX     9787      407       7347
# 394       New York, NY     6575    -3056       2770
# 445      Brentwood, TN     5762       19       4584
# 569         Dallas, TX     4260       53       2860
# 571   Indianapolis, IN     4213     -139       2175
# 732          Tempe, AZ     3002      331       2961
# 850         Warren, PA     2470       82       2997
# 953        Houston, TX     2066      -40        744
# 983        Houston, TX     1944       -1        809

# %%
sectors.get_group(('Energy', ))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:650, in BaseGroupBy._get_indices(self, names)
#     648 try:
#     649     # If the original grouper was a tuple
# --> 650     return [self.indices[name] for name in names]
#     651 except KeyError as err:
#     652     # turns out it wasn't a tuple
#
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:650, in <listcomp>(.0)
#     648 try:
#     649     # If the original grouper was a tuple
# --> 650     return [self.indices[name] for name in names]
#     651 except KeyError as err:
#     652     # turns out it wasn't a tuple
#
# KeyError: ('Energy',)
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# c:\Users\Tom\iCloudDrive\Nauka\Python\Pyton_files\Data-Analysis-with-Pandas-and-Python\section_09\158.ipynb Cell 12 in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Tom/iCloudDrive/Nauka/Python/Pyton_files/Data-Analysis-with-Pandas-and-Python/section_09/158.ipynb#ch0000011?line=0'>1</a> sectors.get_group(('Energy', ))
#
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:745, in BaseGroupBy.get_group(self, name, obj)
#     742 if obj is None:
#     743     obj = self._selected_obj
# --> 745 inds = self._get_index(name)
#     746 if not len(inds):
#     747     raise KeyError(name)
#
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:673, in BaseGroupBy._get_index(self, name)
#     668 @final
#     669 def _get_index(self, name):
#     670     """
#     671     Safe get index, translate keys for datelike to underlying repr.
#     672     """
# --> 673     return self._get_indices([name])[0]
#
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:657, in BaseGroupBy._get_indices(self, names)
#     651     except KeyError as err:
#     652         # turns out it wasn't a tuple
#     653         msg = (
#     654             "must supply a same-length tuple to get_group "
#     655             "with multiple grouping keys"
#     656         )
# --> 657         raise ValueError(msg) from err
#     659 converters = [get_converter(s) for s in index_sample]
#     660 names = (tuple(f(n) for f, n in zip(converters, name)) for name in names)
#
# ValueError: must supply a same-length tuple to get_group with multiple grouping keys

# %%
sectors['Employees'].mean()
# Out:
# Sector               Industry
# Aerospace & Defense  Aerospace and Defense                            48402.850000
# Apparel              Apparel                                          23093.133333
# Business Services    Advertising, marketing                           62050.000000
#                      Diversified Outsourcing Services                 50595.000000
#                      Education                                        15585.000000
#                                                                           ...
# Transportation       Trucking, Truck Leasing                          18939.555556
# Wholesalers          Miscellaneous                                     9200.000000
#                      Wholesalers: Diversified                          9353.240000
#                      Wholesalers: Electronics and Office Equipment    20832.625000
#                      Wholesalers: Food and Grocery                    19317.500000
# Name: Employees, Length: 79, dtype: float64
