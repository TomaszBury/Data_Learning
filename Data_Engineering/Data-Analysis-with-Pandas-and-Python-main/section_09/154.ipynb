# %% [markdown]
# # Groupby

# %%
import pandas as pd

# %%
pd.read_csv('fortune1000.csv')
# Out:
#      Rank                     Company                        Sector  \
# 0       1                     Walmart                     Retailing
# 1       2                 Exxon Mobil                        Energy
# 2       3                       Apple                    Technology
# 3       4          Berkshire Hathaway                    Financials
# 4       5                    McKesson                   Health Care
# ..    ...                         ...                           ...
# 995   996  New York Community Bancorp                    Financials
# 996   997   Portland General Electric                        Energy
# 997   997   Portland General Electric                        Energy
# 998   999                     Wendy’s  Hotels, Resturants & Leisure
# 999  1000           Briggs & Stratton                   Industrials
#
#                                      Industry           Location  Revenue  \
# 0                       General Merchandisers    Bentonville, AR   482130
# ...

# %%
pd.read_csv('fortune1000.csv', index_col='Rank')
# Out:
#                          Company                        Sector  \
# Rank
# 1                        Walmart                     Retailing
# 2                    Exxon Mobil                        Energy
# 3                          Apple                    Technology
# 4             Berkshire Hathaway                    Financials
# 5                       McKesson                   Health Care
# ...                          ...                           ...
# 996   New York Community Bancorp                    Financials
# 997    Portland General Electric                        Energy
# 997    Portland General Electric                        Energy
# 999                      Wendy’s  Hotels, Resturants & Leisure
# 1000           Briggs & Stratton                   Industrials
#
#                                       Industry           Location  Revenue  \
# Rank
# 1                        General Merchandisers    Bentonville, AR   482130
# ...

# %%
fortune = pd.read_csv('fortune1000.csv', index_col='Rank')
fortune.head(n=2)
# Out:
#           Company     Sector               Industry         Location  Revenue  \
# Rank
# 1         Walmart  Retailing  General Merchandisers  Bentonville, AR   482130
# 2     Exxon Mobil     Energy     Petroleum Refining       Irving, TX   246204
#
#       Profits  Employees
# Rank
# 1       14694    2300000
# 2       16150      75600

# %%
fortune.groupby('Industry')

# %%
fortune.groupby('Sector')

# %%
DataFrameGroupBy
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Tom\iCloudDrive\Nauka\Python\Pyton_files\Data-Analysis-with-Pandas-and-Python\section_09\154.ipynb Cell 8 in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Tom/iCloudDrive/Nauka/Python/Pyton_files/Data-Analysis-with-Pandas-and-Python/section_09/154.ipynb#ch0000007?line=0'>1</a> DataFrameGroupBy
#
# NameError: name 'DataFrameGroupBy' is not defined

# %%
sectors = fortune.groupby('Sector')

# %%
sectors

# %%
type(sectors)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy
