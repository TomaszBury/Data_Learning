# %% [markdown]
# # The pandas DtaeTimeIndex object

# %%
import pandas as pd
import datetime as dt

# %%
dates = ['2016-01-02', '2016-04-12', '2009-09-07']
pd.DatetimeIndex(dates)
# Out:
# DatetimeIndex(['2016-01-02', '2016-04-12', '2009-09-07'], dtype='datetime64[ns]', freq=None)

# %%
type(pd.DatetimeIndex(dates))
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
dates = [dt.date(2016,1,10), dt.date(1994,6,13), dt.date(2003,1,13)]

# %%
pd.DatetimeIndex(dates)
# Out:
# DatetimeIndex(['2016-01-10', '1994-06-13', '2003-01-13'], dtype='datetime64[ns]', freq=None)

# %%
type(pd.DatetimeIndex(dates))
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
dt_index = pd.DatetimeIndex([dt.date(2016,1,10),dt.date(2999,12,31),dt.date(1410,12,8)])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\arrays\datetimes.py:2211, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2210 try:
# -> 2211     values, tz_parsed = conversion.datetime_to_datetime64(data.ravel("K"))
#    2212     # If tzaware, these values represent unix timestamps, so we
#    2213     #  return them as i8 to distinguish from wall times
#
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\tslibs\conversion.pyx:360, in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'datetime.date'>
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
dt_index = pd.DatetimeIndex([dt.date(2016,1,10),dt.date(2899,12,31),dt.date(1410,12,8)])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\arrays\datetimes.py:2211, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2210 try:
# -> 2211     values, tz_parsed = conversion.datetime_to_datetime64(data.ravel("K"))
#    2212     # If tzaware, these values represent unix timestamps, so we
#    2213     #  return them as i8 to distinguish from wall times
#
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\tslibs\conversion.pyx:360, in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'datetime.date'>
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
dt_index = pd.DatetimeIndex([dt.date(2016,1,10),dt.date(2799,12,31),dt.date(1410,12,8)])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\arrays\datetimes.py:2211, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2210 try:
# -> 2211     values, tz_parsed = conversion.datetime_to_datetime64(data.ravel("K"))
#    2212     # If tzaware, these values represent unix timestamps, so we
#    2213     #  return them as i8 to distinguish from wall times
#
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\tslibs\conversion.pyx:360, in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'datetime.date'>
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
dt_index = pd.DatetimeIndex([dt.date(2016,1,10),dt.date(2699,12,31),dt.date(1410,12,8)])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\arrays\datetimes.py:2211, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2210 try:
# -> 2211     values, tz_parsed = conversion.datetime_to_datetime64(data.ravel("K"))
#    2212     # If tzaware, these values represent unix timestamps, so we
#    2213     #  return them as i8 to distinguish from wall times
#
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\tslibs\conversion.pyx:360, in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'datetime.date'>
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
dt_index = pd.DatetimeIndex([dt.date(2016,1,10),dt.date(2599,12,31),dt.date(1410,12,8)])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\arrays\datetimes.py:2211, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2210 try:
# -> 2211     values, tz_parsed = conversion.datetime_to_datetime64(data.ravel("K"))
#    2212     # If tzaware, these values represent unix timestamps, so we
#    2213     #  return them as i8 to distinguish from wall times
#
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\tslibs\conversion.pyx:360, in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'datetime.date'>
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
dt_index = pd.DatetimeIndex([dt.date(2016,1,10),dt.date(2499,12,31),dt.date(1410,12,8)])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\arrays\datetimes.py:2211, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2210 try:
# -> 2211     values, tz_parsed = conversion.datetime_to_datetime64(data.ravel("K"))
#    2212     # If tzaware, these values represent unix timestamps, so we
#    2213     #  return them as i8 to distinguish from wall times
#
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\tslibs\conversion.pyx:360, in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'datetime.date'>
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
dt_index = pd.DatetimeIndex([dt.date(2016,1,10),dt.date(2399,12,31),dt.date(1410,12,8)])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\arrays\datetimes.py:2211, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2210 try:
# -> 2211     values, tz_parsed = conversion.datetime_to_datetime64(data.ravel("K"))
#    2212     # If tzaware, these values represent unix timestamps, so we
#    2213     #  return them as i8 to distinguish from wall times
#
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\tslibs\conversion.pyx:360, in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'datetime.date'>
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
dt_index = pd.DatetimeIndex([dt.date(2016,1,10),dt.date(2299,12,31),dt.date(1410,12,8)])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\arrays\datetimes.py:2211, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2210 try:
# -> 2211     values, tz_parsed = conversion.datetime_to_datetime64(data.ravel("K"))
#    2212     # If tzaware, these values represent unix timestamps, so we
#    2213     #  return them as i8 to distinguish from wall times
#
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\tslibs\conversion.pyx:360, in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'datetime.date'>
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
dt_index = pd.DatetimeIndex([dt.date(2016,1,10),dt.date(2199,12,31),dt.date(1410,12,8)])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\arrays\datetimes.py:2211, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2210 try:
# -> 2211     values, tz_parsed = conversion.datetime_to_datetime64(data.ravel("K"))
#    2212     # If tzaware, these values represent unix timestamps, so we
#    2213     #  return them as i8 to distinguish from wall times
#
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\tslibs\conversion.pyx:360, in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'datetime.date'>
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
dt_index = pd.DatetimeIndex([dt.date(2016,1,10),dt.date(2199,12,31),dt.date(1910,12,8)])

# %%
values = [100,200,300]
pd.Series(data = values, index=dt_index)
# Out:
# 2016-01-10    100
# 2199-12-31    200
# 1910-12-08    300
# dtype: int64

# %%
type(pd.Series(data=values, index=dt_index))
# Out:
# pandas.core.series.Series
