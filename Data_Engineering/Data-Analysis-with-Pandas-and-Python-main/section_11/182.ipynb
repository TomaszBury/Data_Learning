# %% [markdown]
# # Import Financial Dataset with pandas_datareader Libray|

# %%
import pandas as pd
import datetime as dt

# %%
from pandas_datareader import data

# %%
data.DataReader(name='MSFT', data_source='yahoo', start='2022-01-01',end='2022-12-31')
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2022-01-03  338.000000  329.779999  335.350006  334.750000  28865100.0
# 2022-01-04  335.200012  326.119995  334.829987  329.010010  32674300.0
# 2022-01-05  326.070007  315.980011  325.859985  316.380005  40054300.0
# 2022-01-06  318.700012  311.489990  313.149994  313.880005  39646100.0
# 2022-01-07  316.500000  310.089996  314.149994  314.040009  32720000.0
# ...                ...         ...         ...         ...         ...
# 2022-07-25  261.500000  256.809998  261.000000  258.829987  21056000.0
# 2022-07-26  259.880005  249.570007  259.859985  251.899994  39348000.0
# 2022-07-27  270.049988  258.850006  261.160004  268.739990  45994000.0
# 2022-07-28  277.839996  267.869995  269.750000  276.410004  33459300.0
# 2022-07-29  282.000000  276.630005  277.700012  280.739990  32129400.0
#
#              Adj Close
# Date
# 2022-01-03  333.283020
# 2022-01-04  327.568176
# 2022-01-05  314.993530
# ...

# %%
stocks = data.DataReader(name='MSFT', data_source='yahoo', start='2021-12-01', end='2022-12-31')
stocks.head(n=3)
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2021-12-01  339.279999  329.390015  335.130005  330.079987  33337600.0
# 2021-12-02  333.489990  327.799988  330.299988  329.489990  30766000.0
# 2021-12-03  332.700012  318.029999  331.989990  323.010010  41779300.0
#
#              Adj Close
# Date
# 2021-12-01  328.633484
# 2021-12-02  328.046051
# 2021-12-03  321.594482

# %%
stocks.values
# Out:
# array([[3.39279999e+02, 3.29390015e+02, 3.35130005e+02, 3.30079987e+02,
#         3.33376000e+07, 3.28633484e+02],
#        [3.33489990e+02, 3.27799988e+02, 3.30299988e+02, 3.29489990e+02,
#         3.07660000e+07, 3.28046051e+02],
#        [3.32700012e+02, 3.18029999e+02, 3.31989990e+02, 3.23010010e+02,
#         4.17793000e+07, 3.21594482e+02],
#        [3.27450012e+02, 3.19230011e+02, 3.23950012e+02, 3.26190002e+02,
#         3.00326000e+07, 3.24760529e+02],
#        [3.35799988e+02, 3.30100006e+02, 3.31640015e+02, 3.34920013e+02,
#         3.10219000e+07, 3.33452271e+02],
#        [3.35500000e+02, 3.30799988e+02, 3.35309998e+02, 3.34970001e+02,
#         2.47610000e+07, 3.33502045e+02],
#        [3.36489990e+02, 3.32119995e+02, 3.34410004e+02, 3.33100006e+02,
#         2.22142000e+07, 3.31640228e+02],
#        [3.43000000e+02, 3.34790009e+02, 3.34980011e+02, 3.42540009e+02,
#         3.80957000e+07, 3.41038879e+02],
# ...

# %%
stocks.columns
# Out:
# Index(['High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close'], dtype='object')

# %%
stocks.index
# Out:
# DatetimeIndex(['2021-12-01', '2021-12-02', '2021-12-03', '2021-12-06',
#                '2021-12-07', '2021-12-08', '2021-12-09', '2021-12-10',
#                '2021-12-13', '2021-12-14',
#                ...
#                '2022-07-18', '2022-07-19', '2022-07-20', '2022-07-21',
#                '2022-07-22', '2022-07-25', '2022-07-26', '2022-07-27',
#                '2022-07-28', '2022-07-29'],
#               dtype='datetime64[ns]', name='Date', length=166, freq=None)

# %%
stocks.axes
# Out:
# [DatetimeIndex(['2021-12-01', '2021-12-02', '2021-12-03', '2021-12-06',
#                 '2021-12-07', '2021-12-08', '2021-12-09', '2021-12-10',
#                 '2021-12-13', '2021-12-14',
#                 ...
#                 '2022-07-18', '2022-07-19', '2022-07-20', '2022-07-21',
#                 '2022-07-22', '2022-07-25', '2022-07-26', '2022-07-27',
#                 '2022-07-28', '2022-07-29'],
#                dtype='datetime64[ns]', name='Date', length=166, freq=None),
#  Index(['High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close'], dtype='object')]
