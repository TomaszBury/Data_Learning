# %% [markdown]
# # the transpose Method

# %%
import pandas as pd

# %%
bigmac = pd.read_csv('bigmac.csv', parse_dates=['Date'], index_col=['Date','Country']).sort_index(level=1,ascending=False)
bigmac.head(n=7)
# Out:
#                       Price in US Dollars
# Date       Country
# 2016-01-01 Vietnam                   2.67
# 2015-07-01 Vietnam                   2.75
# 2015-01-01 Vietnam                   2.81
# 2014-07-01 Vietnam                   2.83
# 2014-01-01 Vietnam                   2.84
# 2016-01-01 Venezuela                 0.66
# 2015-07-01 Venezuela                 0.67

# %%
bigmac.transpose()
# Out:
# Date                2016-01-01 2015-07-01 2015-01-01 2014-07-01 2014-01-01  \
# Country                Vietnam    Vietnam    Vietnam    Vietnam    Vietnam
# Price in US Dollars       2.67       2.75       2.81       2.83       2.84
#
# Date                2016-01-01 2015-07-01 2015-01-01 2014-07-01 2014-01-01  \
# Country              Venezuela  Venezuela  Venezuela  Venezuela  Venezuela
# Price in US Dollars       0.66       0.67       2.53       6.82       7.15
#
# Date                 ... 2015-01-01 2014-07-01 2014-01-01 2013-07-01  \
# Country              ...  Argentina  Argentina  Argentina  Argentina
# Price in US Dollars  ...       3.25       2.57       3.03       3.88
#
# Date                2013-01-01 2012-07-01 2012-01-01 2011-07-01 2010-07-01  \
# Country              Argentina  Argentina  Argentina  Argentina  Argentina
# Price in US Dollars       3.82       4.16       4.64       4.84       3.56
#
# Date                2010-01-01
# Country              Argentina
# ...

# %%
bigmac = bigmac.transpose()

# %%
bigmac
# Out:
# Date                2016-01-01 2015-07-01 2015-01-01 2014-07-01 2014-01-01  \
# Country                Vietnam    Vietnam    Vietnam    Vietnam    Vietnam
# Price in US Dollars       2.67       2.75       2.81       2.83       2.84
#
# Date                2016-01-01 2015-07-01 2015-01-01 2014-07-01 2014-01-01  \
# Country              Venezuela  Venezuela  Venezuela  Venezuela  Venezuela
# Price in US Dollars       0.66       0.67       2.53       6.82       7.15
#
# Date                 ... 2015-01-01 2014-07-01 2014-01-01 2013-07-01  \
# Country              ...  Argentina  Argentina  Argentina  Argentina
# Price in US Dollars  ...       3.25       2.57       3.03       3.88
#
# Date                2013-01-01 2012-07-01 2012-01-01 2011-07-01 2010-07-01  \
# Country              Argentina  Argentina  Argentina  Argentina  Argentina
# Price in US Dollars       3.82       4.16       4.64       4.84       3.56
#
# Date                2010-01-01
# Country              Argentina
# ...

# %%
bigmac.loc[('Price in US Dollars',),:]
# Out:
# Date                2016-01-01 2015-07-01 2015-01-01 2014-07-01 2014-01-01  \
# Country                Vietnam    Vietnam    Vietnam    Vietnam    Vietnam
# Price in US Dollars       2.67       2.75       2.81       2.83       2.84
#
# Date                2016-01-01 2015-07-01 2015-01-01 2014-07-01 2014-01-01  \
# Country              Venezuela  Venezuela  Venezuela  Venezuela  Venezuela
# Price in US Dollars       0.66       0.67       2.53       6.82       7.15
#
# Date                 ... 2015-01-01 2014-07-01 2014-01-01 2013-07-01  \
# Country              ...  Argentina  Argentina  Argentina  Argentina
# Price in US Dollars  ...       3.25       2.57       3.03       3.88
#
# Date                2013-01-01 2012-07-01 2012-01-01 2011-07-01 2010-07-01  \
# Country              Argentina  Argentina  Argentina  Argentina  Argentina
# Price in US Dollars       3.82       4.16       4.64       4.84       3.56
#
# Date                2010-01-01
# Country              Argentina
# ...

# %%
bigmac.loc[('Price in US Dollars',)]
# Out:
# Date        Country
# 2016-01-01  Vietnam      2.67
# 2015-07-01  Vietnam      2.75
# 2015-01-01  Vietnam      2.81
# 2014-07-01  Vietnam      2.83
# 2014-01-01  Vietnam      2.84
#                          ...
# 2012-07-01  Argentina    4.16
# 2012-01-01  Argentina    4.64
# 2011-07-01  Argentina    4.84
# 2010-07-01  Argentina    3.56
# 2010-01-01  Argentina    1.84
# Name: Price in US Dollars, Length: 652, dtype: float64

# %%
bigmac.loc[('Price in US Dollars',),('2010-01-01',)]
# Out:
# C:\Users\Tom\AppData\Local\Temp\ipykernel_3404\1099945445.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   bigmac.loc[('Price in US Dollars',),('2010-01-01',)]
# Country              Uruguay  United States  Ukraine   UAE  Turkey  Thailand  \
# Price in US Dollars     3.32           3.58     1.83  2.99    3.83      2.11
#
# Country              Taiwan  Switzerland  Sweden  Sri Lanka  ...  \
# Price in US Dollars    2.36          6.3    5.51       1.83  ...
#
# Country              Czech Republic  Costa Rica  Colombia  China  Chile  \
# Price in US Dollars            3.71        3.52      3.91   1.83   3.18
#
# Country              Canada  Britain  Brazil  Australia  Argentina
# Price in US Dollars    3.97     3.67    4.76       3.98       1.84
#
# [1 rows x 43 columns]

# %%
bigmac.index.get_level_values(0)
# Out:
# Index(['Price in US Dollars'], dtype='object')

# %%
bigmac.index
# Out:
# Index(['Price in US Dollars'], dtype='object')

# %%
bigmac
# Out:
# Date                2016-01-01 2015-07-01 2015-01-01 2014-07-01 2014-01-01  \
# Country                Vietnam    Vietnam    Vietnam    Vietnam    Vietnam
# Price in US Dollars       2.67       2.75       2.81       2.83       2.84
#
# Date                2016-01-01 2015-07-01 2015-01-01 2014-07-01 2014-01-01  \
# Country              Venezuela  Venezuela  Venezuela  Venezuela  Venezuela
# Price in US Dollars       0.66       0.67       2.53       6.82       7.15
#
# Date                 ... 2015-01-01 2014-07-01 2014-01-01 2013-07-01  \
# Country              ...  Argentina  Argentina  Argentina  Argentina
# Price in US Dollars  ...       3.25       2.57       3.03       3.88
#
# Date                2013-01-01 2012-07-01 2012-01-01 2011-07-01 2010-07-01  \
# Country              Argentina  Argentina  Argentina  Argentina  Argentina
# Price in US Dollars       3.82       4.16       4.64       4.84       3.56
#
# Date                2010-01-01
# Country              Argentina
# ...

# %%
bigmac.loc[('Price in US Dollars',),('2010-01-01','Sri Lanka')]
# Out:
# Price in US Dollars    1.83
# Name: (2010-01-01 00:00:00, Sri Lanka), dtype: float64

# %%
bigmac.loc[('Price in US Dollars',),('2010-01-01','Sri Lanka'):('2010-01-01','Ukraine')]
# Out:
# ---------------------------------------------------------------------------
# UnsortedIndexError                        Traceback (most recent call last)
# c:\Users\Tom\iCloudDrive\Nauka\Python\Pyton_files\Data-Analysis-with-Pandas-and-Python\section_08\144.ipynb Cell 14 in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Tom/iCloudDrive/Nauka/Python/Pyton_files/Data-Analysis-with-Pandas-and-Python/section_08/144.ipynb#ch0000013?line=0'>1</a> bigmac.loc[('Price in US Dollars',),('2010-01-01','Sri Lanka'):('2010-01-01','Ukraine')]
#
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:961, in _LocationIndexer.__getitem__(self, key)
#     959     if self._is_scalar_access(key):
#     960         return self.obj._get_value(*key, takeable=self._takeable)
# --> 961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#     964     axis = self.axis or 0
#
# ...

# %%
bigmac = bigmac.sort_index()

# %%
bigmac.loc[('Price in US Dollars',),('2010-01-01','Sri Lanka'):('2010-01-01','Ukraine')]
# Out:
# ---------------------------------------------------------------------------
# UnsortedIndexError                        Traceback (most recent call last)
# c:\Users\Tom\iCloudDrive\Nauka\Python\Pyton_files\Data-Analysis-with-Pandas-and-Python\section_08\144.ipynb Cell 16 in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Tom/iCloudDrive/Nauka/Python/Pyton_files/Data-Analysis-with-Pandas-and-Python/section_08/144.ipynb#ch0000015?line=0'>1</a> bigmac.loc[('Price in US Dollars',),('2010-01-01','Sri Lanka'):('2010-01-01','Ukraine')]
#
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:961, in _LocationIndexer.__getitem__(self, key)
#     959     if self._is_scalar_access(key):
#     960         return self.obj._get_value(*key, takeable=self._takeable)
# --> 961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#     964     axis = self.axis or 0
#
# ...

# %%
bigmac.sort_index(ascending=[True,True])
# Out:
# Date                2016-01-01 2015-07-01 2015-01-01 2014-07-01 2014-01-01  \
# Country                Vietnam    Vietnam    Vietnam    Vietnam    Vietnam
# Price in US Dollars       2.67       2.75       2.81       2.83       2.84
#
# Date                2016-01-01 2015-07-01 2015-01-01 2014-07-01 2014-01-01  \
# Country              Venezuela  Venezuela  Venezuela  Venezuela  Venezuela
# Price in US Dollars       0.66       0.67       2.53       6.82       7.15
#
# Date                 ... 2015-01-01 2014-07-01 2014-01-01 2013-07-01  \
# Country              ...  Argentina  Argentina  Argentina  Argentina
# Price in US Dollars  ...       3.25       2.57       3.03       3.88
#
# Date                2013-01-01 2012-07-01 2012-01-01 2011-07-01 2010-07-01  \
# Country              Argentina  Argentina  Argentina  Argentina  Argentina
# Price in US Dollars       3.82       4.16       4.64       4.84       3.56
#
# Date                2010-01-01
# Country              Argentina
# ...

# %%
bigmac = pd.read_csv('bigmac.csv',parse_dates=['Date'],index_col=['Date','Country'])
bigmac = bigmac.sort_index()
bigmac
# Out:
#                           Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                     1.84
#            Australia                     3.98
#            Brazil                        4.76
#            Britain                       3.67
#            Canada                        3.97
# ...                                       ...
# 2016-01-01 Ukraine                       1.54
#            United States                 4.93
#            Uruguay                       3.74
#            Venezuela                     0.66
#            Vietnam                       2.67
#
# [652 rows x 1 columns]

# %%
bigmac.transpose()
# Out:
# Date                2010-01-01                                              \
# Country              Argentina Australia Brazil Britain Canada Chile China
# Price in US Dollars       1.84      3.98   4.76    3.67   3.97  3.18  1.83
#
# Date                                                    ...  2016-01-01  \
# Country             Colombia Costa Rica Czech Republic  ... Switzerland
# Price in US Dollars     3.91       3.52           3.71  ...        6.44
#
# Date                                                                    \
# Country             Taiwan Thailand Turkey   UAE Ukraine United States
# Price in US Dollars   2.08     3.09   3.41  3.54    1.54          4.93
#
# Date
# Country             Uruguay Venezuela Vietnam
# Price in US Dollars    3.74      0.66    2.67
#
# [1 rows x 652 columns]

# %%
bigmac.loc[('Price in US Dollars',),('2010-01-01','Sri Lanka'):('2010-01-01','Ukraine')]
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# c:\Users\Tom\iCloudDrive\Nauka\Python\Pyton_files\Data-Analysis-with-Pandas-and-Python\section_08\144.ipynb Cell 20 in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Tom/iCloudDrive/Nauka/Python/Pyton_files/Data-Analysis-with-Pandas-and-Python/section_08/144.ipynb#ch0000019?line=0'>1</a> bigmac.loc[('Price in US Dollars',),('2010-01-01','Sri Lanka'):('2010-01-01','Ukraine')]
#
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:961, in _LocationIndexer.__getitem__(self, key)
#     959     if self._is_scalar_access(key):
#     960         return self.obj._get_value(*key, takeable=self._takeable)
# --> 961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#     964     axis = self.axis or 0
#
# ...

# %%
bigmac.loc[('Price in US Dolars',),('2010-01-01','Sri Lanka')]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\Tom\iCloudDrive\Nauka\Python\Pyton_files\Data-Analysis-with-Pandas-and-Python\section_08\144.ipynb Cell 21 in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Tom/iCloudDrive/Nauka/Python/Pyton_files/Data-Analysis-with-Pandas-and-Python/section_08/144.ipynb#ch0000020?line=0'>1</a> bigmac.loc[('Price in US Dolars',),('2010-01-01','Sri Lanka')]
#
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:961, in _LocationIndexer.__getitem__(self, key)
#     959     if self._is_scalar_access(key):
#     960         return self.obj._get_value(*key, takeable=self._takeable)
# --> 961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#     964     axis = self.axis or 0
#
# ...

# %%
bigmac = bigmac.transpose()

# %%
bigmac
# Out:
# Date                2010-01-01                                              \
# Country              Argentina Australia Brazil Britain Canada Chile China
# Price in US Dollars       1.84      3.98   4.76    3.67   3.97  3.18  1.83
#
# Date                                                    ...  2016-01-01  \
# Country             Colombia Costa Rica Czech Republic  ... Switzerland
# Price in US Dollars     3.91       3.52           3.71  ...        6.44
#
# Date                                                                    \
# Country             Taiwan Thailand Turkey   UAE Ukraine United States
# Price in US Dollars   2.08     3.09   3.41  3.54    1.54          4.93
#
# Date
# Country             Uruguay Venezuela Vietnam
# Price in US Dollars    3.74      0.66    2.67
#
# [1 rows x 652 columns]

# %%
bigmac.loc[('Price in US Dollars',),('2010-01-01','Sri Lanka')]
# Out:
# Price in US Dollars    1.83
# Name: (2010-01-01 00:00:00, Sri Lanka), dtype: float64

# %%
bigmac.loc[('Price in US Dollars',),('2010-01-01','Ukraine')]
# Out:
# Price in US Dollars    1.83
# Name: (2010-01-01 00:00:00, Ukraine), dtype: float64

# %%
bigmac.loc[('Price in US Dollars',),('2010-01-01','Sri Lanka'):('2010-01-01',"Ukraine")]
# Out:
# Date                2010-01-01                                            \
# Country              Sri Lanka Sweden Switzerland Taiwan Thailand Turkey
# Price in US Dollars       1.83   5.51         6.3   2.36     2.11   3.83
#
# Date
# Country               UAE Ukraine
# Price in US Dollars  2.99    1.83

# %%
bigmac.loc[('Price in US Dollars',),(slice(None),'UAE'):(slice(None),'Ukraine')]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Tom\iCloudDrive\Nauka\Python\Pyton_files\Data-Analysis-with-Pandas-and-Python\section_08\144.ipynb Cell 27 in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Tom/iCloudDrive/Nauka/Python/Pyton_files/Data-Analysis-with-Pandas-and-Python/section_08/144.ipynb#ch0000026?line=0'>1</a> bigmac.loc[('Price in US Dollars',),(slice(None),'UAE'):(slice(None),'Ukraine')]
#
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:961, in _LocationIndexer.__getitem__(self, key)
#     959     if self._is_scalar_access(key):
#     960         return self.obj._get_value(*key, takeable=self._takeable)
# --> 961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#     964     axis = self.axis or 0
#
# ...

# %%
bigmac
# Out:
# Date                2010-01-01                                              \
# Country              Argentina Australia Brazil Britain Canada Chile China
# Price in US Dollars       1.84      3.98   4.76    3.67   3.97  3.18  1.83
#
# Date                                                    ...  2016-01-01  \
# Country             Colombia Costa Rica Czech Republic  ... Switzerland
# Price in US Dollars     3.91       3.52           3.71  ...        6.44
#
# Date                                                                    \
# Country             Taiwan Thailand Turkey   UAE Ukraine United States
# Price in US Dollars   2.08     3.09   3.41  3.54    1.54          4.93
#
# Date
# Country             Uruguay Venezuela Vietnam
# Price in US Dollars    3.74      0.66    2.67
#
# [1 rows x 652 columns]

# %%
bigmac.loc[('Price in US Dollars',),('2010-01-01',):('2016-01-01',)]
# Out:
# Date                2010-01-01                                              \
# Country              Argentina Australia Brazil Britain Canada Chile China
# Price in US Dollars       1.84      3.98   4.76    3.67   3.97  3.18  1.83
#
# Date                                                    ...  2016-01-01  \
# Country             Colombia Costa Rica Czech Republic  ... Switzerland
# Price in US Dollars     3.91       3.52           3.71  ...        6.44
#
# Date                                                                    \
# Country             Taiwan Thailand Turkey   UAE Ukraine United States
# Price in US Dollars   2.08     3.09   3.41  3.54    1.54          4.93
#
# Date
# Country             Uruguay Venezuela Vietnam
# Price in US Dollars    3.74      0.66    2.67
#
# [1 rows x 652 columns]

# %%
bigmac.loc[('Price in US Dollars',),(,'Chile',):(,'Ukraine')]
# Out:
#   Input In [51]
#     bigmac.loc[('Price in US Dollars',),(,'Chile',):(,'Ukraine')]
#                                          ^
# SyntaxError: invalid syntax

# %%
bigmac.loc[('Price in US Dollars',),(,'Chile'):(,'Ukraine')]
# Out:
#   Input In [52]
#     bigmac.loc[('Price in US Dollars',),(,'Chile'):(,'Ukraine')]
#                                          ^
# SyntaxError: invalid syntax

# %%
bigmac.loc[('Price in US Dollars',),('Chile'):('Ukraine')]
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\tslibs\conversion.pyx:649, in pandas._libs.tslibs.conversion._convert_str_to_tsobject()
#
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\tslibs\parsing.pyx:281, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\dateutil\parser\_parser.py:1368, in parse(timestr, parserinfo, **kwargs)
#    1367 else:
# -> 1368     return DEFAULTPARSER.parse(timestr, **kwargs)
#
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\dateutil\parser\_parser.py:643, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     642 if res is None:
# ...

# %%
bigmac
# Out:
# Date                2010-01-01                                              \
# Country              Argentina Australia Brazil Britain Canada Chile China
# Price in US Dollars       1.84      3.98   4.76    3.67   3.97  3.18  1.83
#
# Date                                                    ...  2016-01-01  \
# Country             Colombia Costa Rica Czech Republic  ... Switzerland
# Price in US Dollars     3.91       3.52           3.71  ...        6.44
#
# Date                                                                    \
# Country             Taiwan Thailand Turkey   UAE Ukraine United States
# Price in US Dollars   2.08     3.09   3.41  3.54    1.54          4.93
#
# Date
# Country             Uruguay Venezuela Vietnam
# Price in US Dollars    3.74      0.66    2.67
#
# [1 rows x 652 columns]

# %%
bigmac.loc[('Price in US Dollars',),('2010-01-01'):('2016-01-01')]
# Out:
# Date                2010-01-01                                              \
# Country              Argentina Australia Brazil Britain Canada Chile China
# Price in US Dollars       1.84      3.98   4.76    3.67   3.97  3.18  1.83
#
# Date                                                    ...  2016-01-01  \
# Country             Colombia Costa Rica Czech Republic  ... Switzerland
# Price in US Dollars     3.91       3.52           3.71  ...        6.44
#
# Date                                                                    \
# Country             Taiwan Thailand Turkey   UAE Ukraine United States
# Price in US Dollars   2.08     3.09   3.41  3.54    1.54          4.93
#
# Date
# Country             Uruguay Venezuela Vietnam
# Price in US Dollars    3.74      0.66    2.67
#
# [1 rows x 652 columns]
