# %% [markdown]
# # Create a Multiindex with the set_index Method

# %%
import pandas as pd

# %%
bigmac = pd.read_csv('bigmac.csv', parse_dates=['Date'])
bigmac.head(3)
# Out:
#         Date    Country  Price in US Dollars
# 0 2016-01-01  Argentina                 2.39
# 1 2016-01-01  Australia                 3.74
# 2 2016-01-01     Brazil                 3.35

# %%
bigmac.set_index('Date')
# Out:
#                   Country  Price in US Dollars
# Date
# 2016-01-01      Argentina                 2.39
# 2016-01-01      Australia                 3.74
# 2016-01-01         Brazil                 3.35
# 2016-01-01        Britain                 4.22
# 2016-01-01         Canada                 4.14
# ...                   ...                  ...
# 2010-01-01         Turkey                 3.83
# 2010-01-01            UAE                 2.99
# 2010-01-01        Ukraine                 1.83
# 2010-01-01  United States                 3.58
# 2010-01-01        Uruguay                 3.32
#
# [652 rows x 2 columns]

# %%
bigmac.set_index(keys=['Date', 'Country'])
# Out:
#                           Price in US Dollars
# Date       Country
# 2016-01-01 Argentina                     2.39
#            Australia                     3.74
#            Brazil                        3.35
#            Britain                       4.22
#            Canada                        4.14
# ...                                       ...
# 2010-01-01 Turkey                        3.83
#            UAE                           2.99
#            Ukraine                       1.83
#            United States                 3.58
#            Uruguay                       3.32
#
# [652 rows x 1 columns]

# %%
bigmac.index
# Out:
# RangeIndex(start=0, stop=652, step=1)

# %%
bigmac.index.index
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Tom\iCloudDrive\Nauka\Python\Pyton_files\Data-Analysis-with-Pandas-and-Python\section_08\136.ipynb Cell 7 in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Tom/iCloudDrive/Nauka/Python/Pyton_files/Data-Analysis-with-Pandas-and-Python/section_08/136.ipynb#ch0000006?line=0'>1</a> bigmac.index.index
#
# AttributeError: 'RangeIndex' object has no attribute 'index'

# %%
bigmac.index[0]
# Out:
# 0

# %%
bigmac.index['2016-01-01']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\Tom\iCloudDrive\Nauka\Python\Pyton_files\Data-Analysis-with-Pandas-and-Python\section_08\136.ipynb Cell 9 in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Tom/iCloudDrive/Nauka/Python/Pyton_files/Data-Analysis-with-Pandas-and-Python/section_08/136.ipynb#ch0000008?line=0'>1</a> bigmac.index['2016-01-01']
#
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\range.py:935, in RangeIndex.__getitem__(self, key)
#     931         raise IndexError(
#     932             f"index {key} is out of bounds for axis 0 with size {len(self)}"
#     933         ) from err
#     934 elif is_scalar(key):
# --> 935     raise IndexError(
#     936         "only integers, slices (`:`), "
#     937         "ellipsis (`...`), numpy.newaxis (`None`) "
# ...

# %%
bigmac.loc['2016-01-01']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\Tom\iCloudDrive\Nauka\Python\Pyton_files\Data-Analysis-with-Pandas-and-Python\section_08\136.ipynb Cell 10 in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Tom/iCloudDrive/Nauka/Python/Pyton_files/Data-Analysis-with-Pandas-and-Python/section_08/136.ipynb#ch0000009?line=0'>1</a> bigmac.loc['2016-01-01']
#
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:1202, in _LocIndexer._getitem_axis(self, key, axis)
#    1200 # fall thru to straight lookup
# ...

# %%
bigmac.iloc[0]
# Out:
# Date                   2016-01-01 00:00:00
# Country                          Argentina
# Price in US Dollars                   2.39
# Name: 0, dtype: object

# %%
bigmac.iloc[0][0]
# Out:
# Timestamp('2016-01-01 00:00:00')

# %%
bigmac.loc['Argentina']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\Tom\iCloudDrive\Nauka\Python\Pyton_files\Data-Analysis-with-Pandas-and-Python\section_08\136.ipynb Cell 13 in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Tom/iCloudDrive/Nauka/Python/Pyton_files/Data-Analysis-with-Pandas-and-Python/section_08/136.ipynb#ch0000012?line=0'>1</a> bigmac.loc['Argentina']
#
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:1202, in _LocIndexer._getitem_axis(self, key, axis)
#    1200 # fall thru to straight lookup
# ...

# %%
bigmac
# Out:
#           Date        Country  Price in US Dollars
# 0   2016-01-01      Argentina                 2.39
# 1   2016-01-01      Australia                 3.74
# 2   2016-01-01         Brazil                 3.35
# 3   2016-01-01        Britain                 4.22
# 4   2016-01-01         Canada                 4.14
# ..         ...            ...                  ...
# 647 2010-01-01         Turkey                 3.83
# 648 2010-01-01            UAE                 2.99
# 649 2010-01-01        Ukraine                 1.83
# 650 2010-01-01  United States                 3.58
# 651 2010-01-01        Uruguay                 3.32
#
# [652 rows x 3 columns]

# %%
bigmac.set_index(keys=['Country', 'Date'])
# Out:
#                           Price in US Dollars
# Country       Date
# Argentina     2016-01-01                 2.39
# Australia     2016-01-01                 3.74
# Brazil        2016-01-01                 3.35
# Britain       2016-01-01                 4.22
# Canada        2016-01-01                 4.14
# ...                                       ...
# Turkey        2010-01-01                 3.83
# UAE           2010-01-01                 2.99
# Ukraine       2010-01-01                 1.83
# United States 2010-01-01                 3.58
# Uruguay       2010-01-01                 3.32
#
# [652 rows x 1 columns]

# %%
bigmac = bigmac.set_index(keys=['Country','Date'])

# %%
bigmac
# Out:
#                           Price in US Dollars
# Country       Date
# Argentina     2016-01-01                 2.39
# Australia     2016-01-01                 3.74
# Brazil        2016-01-01                 3.35
# Britain       2016-01-01                 4.22
# Canada        2016-01-01                 4.14
# ...                                       ...
# Turkey        2010-01-01                 3.83
# UAE           2010-01-01                 2.99
# Ukraine       2010-01-01                 1.83
# United States 2010-01-01                 3.58
# Uruguay       2010-01-01                 3.32
#
# [652 rows x 1 columns]

# %%
bigmac.loc['Argentina']
# Out:
#             Price in US Dollars
# Date
# 2016-01-01                 2.39
# 2015-07-01                 3.07
# 2015-01-01                 3.25
# 2014-07-01                 2.57
# 2014-01-01                 3.03
# 2013-07-01                 3.88
# 2013-01-01                 3.82
# 2012-07-01                 4.16
# 2012-01-01                 4.64
# 2011-07-01                 4.84
# 2010-07-01                 3.56
# 2010-01-01                 1.84

# %%
bigmac.loc[*]['2016-01-01']
# Out:
#   Input In [25]
#     bigmac.loc[*]['2016-01-01']
#                ^
# SyntaxError: invalid syntax

# %%
bigmac.loc['United States']
# Out:
#             Price in US Dollars
# Date
# 2016-01-01                 4.93
# 2015-07-01                 4.79
# 2015-01-01                 4.79
# 2014-07-01                 4.80
# 2014-01-01                 4.62
# 2013-07-01                 4.56
# 2013-01-01                 4.37
# 2012-07-01                 4.33
# 2012-01-01                 4.20
# 2011-07-01                 4.07
# 2010-07-01                 3.73
# 2010-01-01                 3.58

# %%
bigmac.nunique()
# Out:
# Price in US Dollars    330
# dtype: int64

# %%
bigmac = pd.read_csv('bigmac.csv', parse_dates=['Date'])
bigmac.head(n=2)
# Out:
#         Date    Country  Price in US Dollars
# 0 2016-01-01  Argentina                 2.39
# 1 2016-01-01  Australia                 3.74

# %%
bigmac.nunique()
# Out:
# Date                    12
# Country                 58
# Price in US Dollars    330
# dtype: int64

# %%
bigmac = bigmac.set_index(keys=['Date', 'Country'])

# %%
bigmac.head(n=7)
# Out:
#                       Price in US Dollars
# Date       Country
# 2016-01-01 Argentina                 2.39
#            Australia                 3.74
#            Brazil                    3.35
#            Britain                   4.22
#            Canada                    4.14
#            Chile                     2.94
#            China                     2.68

# %%
bigmac.loc['2016-01-01']
# Out:
#                 Price in US Dollars
# Country
# Argentina                      2.39
# Australia                      3.74
# Brazil                         3.35
# Britain                        4.22
# Canada                         4.14
# Chile                          2.94
# China                          2.68
# Colombia                       2.43
# Costa Rica                     4.02
# Czech Republic                 2.98
# Denmark                        4.32
# Egypt                          2.16
# Euro area                      4.00
# Hong Kong                      2.48
# Hungary                        3.08
# India                          1.90
# Indonesia                      2.19
# Israel                         4.29
# Japan                          3.12
# Malaysia                       1.82
# Mexico                         2.81
# New Zealand                    3.91
# Norway                         5.21
# Pakistan                       2.86
# Peru                           2.93
# ...

# %%
bigmac.sort_index()
# Out:
#                           Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                     1.84
#            Australia                     3.98
#            Brazil                        4.76
#            Britain                       3.67
#            Canada                        3.97
# ...                                       ...
# 2016-01-01 Ukraine                       1.54
#            United States                 4.93
#            Uruguay                       3.74
#            Venezuela                     0.66
#            Vietnam                       2.67
#
# [652 rows x 1 columns]

# %%
bigmac.sort_index().tail(n=45)
# Out:
#                            Price in US Dollars
# Date       Country
# 2016-01-01 Czech Republic                 2.98
#            Denmark                        4.32
#            Egypt                          2.16
#            Estonia                        3.23
#            Euro area                      4.00
#            Finland                        4.41
#            France                         4.41
#            Germany                        3.86
#            Greece                         3.60
#            Hong Kong                      2.48
#            Hungary                        3.08
#            India                          1.90
#            Indonesia                      2.19
#            Ireland                        4.25
#            Israel                         4.29
#            Italy                          4.30
#            Japan                          3.12
#            Malaysia                       1.82
# ...

# %%
bigmac = bigmac.sort_index()

# %%
bigmac
# Out:
#                           Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                     1.84
#            Australia                     3.98
#            Brazil                        4.76
#            Britain                       3.67
#            Canada                        3.97
# ...                                       ...
# 2016-01-01 Ukraine                       1.54
#            United States                 4.93
#            Uruguay                       3.74
#            Venezuela                     0.66
#            Vietnam                       2.67
#
# [652 rows x 1 columns]

# %%
bigmac.index
# Out:
# MultiIndex([('2010-01-01',      'Argentina'),
#             ('2010-01-01',      'Australia'),
#             ('2010-01-01',         'Brazil'),
#             ('2010-01-01',        'Britain'),
#             ('2010-01-01',         'Canada'),
#             ('2010-01-01',          'Chile'),
#             ('2010-01-01',          'China'),
#             ('2010-01-01',       'Colombia'),
#             ('2010-01-01',     'Costa Rica'),
#             ('2010-01-01', 'Czech Republic'),
#             ...
#             ('2016-01-01',    'Switzerland'),
#             ('2016-01-01',         'Taiwan'),
#             ('2016-01-01',       'Thailand'),
#             ('2016-01-01',         'Turkey'),
#             ('2016-01-01',            'UAE'),
#             ('2016-01-01',        'Ukraine'),
#             ('2016-01-01',  'United States'),
#             ('2016-01-01',        'Uruguay'),
#             ('2016-01-01',      'Venezuela'),
#             ('2016-01-01',        'Vietnam')],
# ...

# %%
bigmac.loc['2016-01-01','Ukraine']
# Out:
# Price in US Dollars    1.54
# Name: (2016-01-01 00:00:00, Ukraine), dtype: float64

# %%
bigmac.index.names
# Out:
# FrozenList(['Date', 'Country'])

# %%
bigmac.loc['2010-01-01','Ukraine']
# Out:
# Price in US Dollars    1.83
# Name: (2010-01-01 00:00:00, Ukraine), dtype: float64

# %%
bigmac.index
# Out:
# MultiIndex([('2010-01-01',      'Argentina'),
#             ('2010-01-01',      'Australia'),
#             ('2010-01-01',         'Brazil'),
#             ('2010-01-01',        'Britain'),
#             ('2010-01-01',         'Canada'),
#             ('2010-01-01',          'Chile'),
#             ('2010-01-01',          'China'),
#             ('2010-01-01',       'Colombia'),
#             ('2010-01-01',     'Costa Rica'),
#             ('2010-01-01', 'Czech Republic'),
#             ...
#             ('2016-01-01',    'Switzerland'),
#             ('2016-01-01',         'Taiwan'),
#             ('2016-01-01',       'Thailand'),
#             ('2016-01-01',         'Turkey'),
#             ('2016-01-01',            'UAE'),
#             ('2016-01-01',        'Ukraine'),
#             ('2016-01-01',  'United States'),
#             ('2016-01-01',        'Uruguay'),
#             ('2016-01-01',      'Venezuela'),
#             ('2016-01-01',        'Vietnam')],
# ...

# %%
type(bigmac.index)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
bigmac.index[0]
# Out:
# (Timestamp('2010-01-01 00:00:00'), 'Argentina')

# %%
type(bigmac.index[10])
# Out:
# tuple

# %%
bigmac.index[10]
# Out:
# (Timestamp('2010-01-01 00:00:00'), 'Denmark')
