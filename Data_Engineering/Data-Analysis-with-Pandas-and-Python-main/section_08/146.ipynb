# %% [markdown]
# # The  .stack() Method

# %%
import pandas as pd

# %%
pd.read_csv('worldstats.csv')
# Out:
#           country  year   Population           GDP
# 0      Arab World  2015  392022276.0  2.530102e+12
# 1      Arab World  2014  384222592.0  2.873600e+12
# 2      Arab World  2013  376504253.0  2.846994e+12
# 3      Arab World  2012  368802611.0  2.773270e+12
# 4      Arab World  2011  361031820.0  2.497945e+12
# ...           ...   ...          ...           ...
# 11206    Zimbabwe  1964    4279561.0  1.217138e+09
# 11207    Zimbabwe  1963    4140804.0  1.159512e+09
# 11208    Zimbabwe  1962    4006262.0  1.117602e+09
# 11209    Zimbabwe  1961    3876638.0  1.096647e+09
# 11210    Zimbabwe  1960    3752390.0  1.052990e+09
#
# [11211 rows x 4 columns]

# %%
pd.read_csv('worldstats.csv', index_col=['country', 'year'])
# Out:
#                   Population           GDP
# country    year
# Arab World 2015  392022276.0  2.530102e+12
#            2014  384222592.0  2.873600e+12
#            2013  376504253.0  2.846994e+12
#            2012  368802611.0  2.773270e+12
#            2011  361031820.0  2.497945e+12
# ...                      ...           ...
# Zimbabwe   1964    4279561.0  1.217138e+09
#            1963    4140804.0  1.159512e+09
#            1962    4006262.0  1.117602e+09
#            1961    3876638.0  1.096647e+09
#            1960    3752390.0  1.052990e+09
#
# [11211 rows x 2 columns]

# %%
world_stats = pd.read_csv('worldstats.csv', index_col=['country', 'year'])
world_stats.head(n=2)
# Out:
#                   Population           GDP
# country    year
# Arab World 2015  392022276.0  2.530102e+12
#            2014  384222592.0  2.873600e+12

# %%
world_stats.index
# Out:
# MultiIndex([('Arab World', 2015),
#             ('Arab World', 2014),
#             ('Arab World', 2013),
#             ('Arab World', 2012),
#             ('Arab World', 2011),
#             ('Arab World', 2010),
#             ('Arab World', 2009),
#             ('Arab World', 2008),
#             ('Arab World', 2007),
#             ('Arab World', 2006),
#             ...
#             (  'Zimbabwe', 1969),
#             (  'Zimbabwe', 1968),
#             (  'Zimbabwe', 1967),
#             (  'Zimbabwe', 1966),
#             (  'Zimbabwe', 1965),
#             (  'Zimbabwe', 1964),
#             (  'Zimbabwe', 1963),
#             (  'Zimbabwe', 1962),
#             (  'Zimbabwe', 1961),
#             (  'Zimbabwe', 1960)],
#            names=['country', 'year'], length=11211)

# %%
world_stats.index.names
# Out:
# FrozenList(['country', 'year'])

# %%
world_stats.index.set_names(['Coutry', ' Year'])
# Out:
# MultiIndex([('Arab World', 2015),
#             ('Arab World', 2014),
#             ('Arab World', 2013),
#             ('Arab World', 2012),
#             ('Arab World', 2011),
#             ('Arab World', 2010),
#             ('Arab World', 2009),
#             ('Arab World', 2008),
#             ('Arab World', 2007),
#             ('Arab World', 2006),
#             ...
#             (  'Zimbabwe', 1969),
#             (  'Zimbabwe', 1968),
#             (  'Zimbabwe', 1967),
#             (  'Zimbabwe', 1966),
#             (  'Zimbabwe', 1965),
#             (  'Zimbabwe', 1964),
#             (  'Zimbabwe', 1963),
#             (  'Zimbabwe', 1962),
#             (  'Zimbabwe', 1961),
#             (  'Zimbabwe', 1960)],
#            names=['Coutry', ' Year'], length=11211)

# %%
world_stats = world_stats.index.set_names(['Coutry', 'Year'])

# %%
world_stats
# Out:
# MultiIndex([('Arab World', 2015),
#             ('Arab World', 2014),
#             ('Arab World', 2013),
#             ('Arab World', 2012),
#             ('Arab World', 2011),
#             ('Arab World', 2010),
#             ('Arab World', 2009),
#             ('Arab World', 2008),
#             ('Arab World', 2007),
#             ('Arab World', 2006),
#             ...
#             (  'Zimbabwe', 1969),
#             (  'Zimbabwe', 1968),
#             (  'Zimbabwe', 1967),
#             (  'Zimbabwe', 1966),
#             (  'Zimbabwe', 1965),
#             (  'Zimbabwe', 1964),
#             (  'Zimbabwe', 1963),
#             (  'Zimbabwe', 1962),
#             (  'Zimbabwe', 1961),
#             (  'Zimbabwe', 1960)],
#            names=['Coutry', 'Year'], length=11211)

# %%
world_stats = pd.read_csv('worldstats.csv', index_col=['country', 'year']).index.set_names(['Country', 'Year'])
world_stats
# Out:
# MultiIndex([('Arab World', 2015),
#             ('Arab World', 2014),
#             ('Arab World', 2013),
#             ('Arab World', 2012),
#             ('Arab World', 2011),
#             ('Arab World', 2010),
#             ('Arab World', 2009),
#             ('Arab World', 2008),
#             ('Arab World', 2007),
#             ('Arab World', 2006),
#             ...
#             (  'Zimbabwe', 1969),
#             (  'Zimbabwe', 1968),
#             (  'Zimbabwe', 1967),
#             (  'Zimbabwe', 1966),
#             (  'Zimbabwe', 1965),
#             (  'Zimbabwe', 1964),
#             (  'Zimbabwe', 1963),
#             (  'Zimbabwe', 1962),
#             (  'Zimbabwe', 1961),
#             (  'Zimbabwe', 1960)],
#            names=['Country', 'Year'], length=11211)

# %%
wrold_stats = pd.read_csv('worldstats.csv')
world_stats
# Out:
# MultiIndex([('Arab World', 2015),
#             ('Arab World', 2014),
#             ('Arab World', 2013),
#             ('Arab World', 2012),
#             ('Arab World', 2011),
#             ('Arab World', 2010),
#             ('Arab World', 2009),
#             ('Arab World', 2008),
#             ('Arab World', 2007),
#             ('Arab World', 2006),
#             ...
#             (  'Zimbabwe', 1969),
#             (  'Zimbabwe', 1968),
#             (  'Zimbabwe', 1967),
#             (  'Zimbabwe', 1966),
#             (  'Zimbabwe', 1965),
#             (  'Zimbabwe', 1964),
#             (  'Zimbabwe', 1963),
#             (  'Zimbabwe', 1962),
#             (  'Zimbabwe', 1961),
#             (  'Zimbabwe', 1960)],
#            names=['Country', 'Year'], length=11211)

# %%
pd.read_csv('worldstats.csv')
# Out:
#           country  year   Population           GDP
# 0      Arab World  2015  392022276.0  2.530102e+12
# 1      Arab World  2014  384222592.0  2.873600e+12
# 2      Arab World  2013  376504253.0  2.846994e+12
# 3      Arab World  2012  368802611.0  2.773270e+12
# 4      Arab World  2011  361031820.0  2.497945e+12
# ...           ...   ...          ...           ...
# 11206    Zimbabwe  1964    4279561.0  1.217138e+09
# 11207    Zimbabwe  1963    4140804.0  1.159512e+09
# 11208    Zimbabwe  1962    4006262.0  1.117602e+09
# 11209    Zimbabwe  1961    3876638.0  1.096647e+09
# 11210    Zimbabwe  1960    3752390.0  1.052990e+09
#
# [11211 rows x 4 columns]

# %%
world_stats = pd.read_csv('worldstats.csv')

# %%
world_stats
# Out:
#           country  year   Population           GDP
# 0      Arab World  2015  392022276.0  2.530102e+12
# 1      Arab World  2014  384222592.0  2.873600e+12
# 2      Arab World  2013  376504253.0  2.846994e+12
# 3      Arab World  2012  368802611.0  2.773270e+12
# 4      Arab World  2011  361031820.0  2.497945e+12
# ...           ...   ...          ...           ...
# 11206    Zimbabwe  1964    4279561.0  1.217138e+09
# 11207    Zimbabwe  1963    4140804.0  1.159512e+09
# 11208    Zimbabwe  1962    4006262.0  1.117602e+09
# 11209    Zimbabwe  1961    3876638.0  1.096647e+09
# 11210    Zimbabwe  1960    3752390.0  1.052990e+09
#
# [11211 rows x 4 columns]

# %%
world_stats.set_index(['country', 'year'])
# Out:
#                   Population           GDP
# country    year
# Arab World 2015  392022276.0  2.530102e+12
#            2014  384222592.0  2.873600e+12
#            2013  376504253.0  2.846994e+12
#            2012  368802611.0  2.773270e+12
#            2011  361031820.0  2.497945e+12
# ...                      ...           ...
# Zimbabwe   1964    4279561.0  1.217138e+09
#            1963    4140804.0  1.159512e+09
#            1962    4006262.0  1.117602e+09
#            1961    3876638.0  1.096647e+09
#            1960    3752390.0  1.052990e+09
#
# [11211 rows x 2 columns]

# %%
world_stats
# Out:
#           country  year   Population           GDP
# 0      Arab World  2015  392022276.0  2.530102e+12
# 1      Arab World  2014  384222592.0  2.873600e+12
# 2      Arab World  2013  376504253.0  2.846994e+12
# 3      Arab World  2012  368802611.0  2.773270e+12
# 4      Arab World  2011  361031820.0  2.497945e+12
# ...           ...   ...          ...           ...
# 11206    Zimbabwe  1964    4279561.0  1.217138e+09
# 11207    Zimbabwe  1963    4140804.0  1.159512e+09
# 11208    Zimbabwe  1962    4006262.0  1.117602e+09
# 11209    Zimbabwe  1961    3876638.0  1.096647e+09
# 11210    Zimbabwe  1960    3752390.0  1.052990e+09
#
# [11211 rows x 4 columns]

# %%
world_stats = world_stats.set_index(['country', 'year'])

# %%
world_stats
# Out:
#                   Population           GDP
# country    year
# Arab World 2015  392022276.0  2.530102e+12
#            2014  384222592.0  2.873600e+12
#            2013  376504253.0  2.846994e+12
#            2012  368802611.0  2.773270e+12
#            2011  361031820.0  2.497945e+12
# ...                      ...           ...
# Zimbabwe   1964    4279561.0  1.217138e+09
#            1963    4140804.0  1.159512e+09
#            1962    4006262.0  1.117602e+09
#            1961    3876638.0  1.096647e+09
#            1960    3752390.0  1.052990e+09
#
# [11211 rows x 2 columns]

# %%
world_stats.index.set_names(['Country', 'Year'])
# Out:
# MultiIndex([('Arab World', 2015),
#             ('Arab World', 2014),
#             ('Arab World', 2013),
#             ('Arab World', 2012),
#             ('Arab World', 2011),
#             ('Arab World', 2010),
#             ('Arab World', 2009),
#             ('Arab World', 2008),
#             ('Arab World', 2007),
#             ('Arab World', 2006),
#             ...
#             (  'Zimbabwe', 1969),
#             (  'Zimbabwe', 1968),
#             (  'Zimbabwe', 1967),
#             (  'Zimbabwe', 1966),
#             (  'Zimbabwe', 1965),
#             (  'Zimbabwe', 1964),
#             (  'Zimbabwe', 1963),
#             (  'Zimbabwe', 1962),
#             (  'Zimbabwe', 1961),
#             (  'Zimbabwe', 1960)],
#            names=['Country', 'Year'], length=11211)

# %%
wrold_stats.head(n=2)
# Out:
#       country  year   Population           GDP
# 0  Arab World  2015  392022276.0  2.530102e+12
# 1  Arab World  2014  384222592.0  2.873600e+12

# %%
world_stats
# Out:
#                   Population           GDP
# country    year
# Arab World 2015  392022276.0  2.530102e+12
#            2014  384222592.0  2.873600e+12
#            2013  376504253.0  2.846994e+12
#            2012  368802611.0  2.773270e+12
#            2011  361031820.0  2.497945e+12
# ...                      ...           ...
# Zimbabwe   1964    4279561.0  1.217138e+09
#            1963    4140804.0  1.159512e+09
#            1962    4006262.0  1.117602e+09
#            1961    3876638.0  1.096647e+09
#            1960    3752390.0  1.052990e+09
#
# [11211 rows x 2 columns]

# %%
world_stats.index.set_names(names=['Country', 'Year'])
# Out:
# MultiIndex([('Arab World', 2015),
#             ('Arab World', 2014),
#             ('Arab World', 2013),
#             ('Arab World', 2012),
#             ('Arab World', 2011),
#             ('Arab World', 2010),
#             ('Arab World', 2009),
#             ('Arab World', 2008),
#             ('Arab World', 2007),
#             ('Arab World', 2006),
#             ...
#             (  'Zimbabwe', 1969),
#             (  'Zimbabwe', 1968),
#             (  'Zimbabwe', 1967),
#             (  'Zimbabwe', 1966),
#             (  'Zimbabwe', 1965),
#             (  'Zimbabwe', 1964),
#             (  'Zimbabwe', 1963),
#             (  'Zimbabwe', 1962),
#             (  'Zimbabwe', 1961),
#             (  'Zimbabwe', 1960)],
#            names=['Country', 'Year'], length=11211)

# %%
world_stats
# Out:
#                   Population           GDP
# country    year
# Arab World 2015  392022276.0  2.530102e+12
#            2014  384222592.0  2.873600e+12
#            2013  376504253.0  2.846994e+12
#            2012  368802611.0  2.773270e+12
#            2011  361031820.0  2.497945e+12
# ...                      ...           ...
# Zimbabwe   1964    4279561.0  1.217138e+09
#            1963    4140804.0  1.159512e+09
#            1962    4006262.0  1.117602e+09
#            1961    3876638.0  1.096647e+09
#            1960    3752390.0  1.052990e+09
#
# [11211 rows x 2 columns]

# %%
world_stats.index = world_stats.index.set_names(names=['Country', 'Year'])

# %%
world_stats.head(n=2)
# Out:
#                   Population           GDP
# Country    Year
# Arab World 2015  392022276.0  2.530102e+12
#            2014  384222592.0  2.873600e+12

# %%
world_stats.stack()
# Out:
# Country     Year
# Arab World  2015  Population    3.920223e+08
#                   GDP           2.530102e+12
#             2014  Population    3.842226e+08
#                   GDP           2.873600e+12
#             2013  Population    3.765043e+08
#                                     ...
# Zimbabwe    1962  GDP           1.117602e+09
#             1961  Population    3.876638e+06
#                   GDP           1.096647e+09
#             1960  Population    3.752390e+06
#                   GDP           1.052990e+09
# Length: 22422, dtype: float64

# %%
world_stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 11211 entries, ('Arab World', 2015) to ('Zimbabwe', 1960)
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Population  11211 non-null  float64
#  1   GDP         11211 non-null  float64
# dtypes: float64(2)
# memory usage: 220.7+ KB

# %%
world_stats.stack().info()
# Out:
# <class 'pandas.core.series.Series'>
# MultiIndex: 22422 entries, ('Arab World', 2015, 'Population') to ('Zimbabwe', 1960, 'GDP')
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 22422 non-null  float64
# dtypes: float64(1)
# memory usage: 275.6+ KB

# %%
type(world_stats.stack())
# Out:
# pandas.core.series.Series

# %%
world_stats.stack().to_frame()
# Out:
#                                        0
# Country    Year
# Arab World 2015 Population  3.920223e+08
#                 GDP         2.530102e+12
#            2014 Population  3.842226e+08
#                 GDP         2.873600e+12
#            2013 Population  3.765043e+08
# ...                                  ...
# Zimbabwe   1962 GDP         1.117602e+09
#            1961 Population  3.876638e+06
#                 GDP         1.096647e+09
#            1960 Population  3.752390e+06
#                 GDP         1.052990e+09
#
# [22422 rows x 1 columns]

# %%
world_stats.stack().to_frame().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 22422 entries, ('Arab World', 2015, 'Population') to ('Zimbabwe', 1960, 'GDP')
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       22422 non-null  float64
# dtypes: float64(1)
# memory usage: 275.6+ KB

# %%
world_stats_df = world_stats.stack().to_frame()

# %%
world_stats_df.rename(columns={0:'Statistics'})
# Out:
#                               Statistics
# Country    Year
# Arab World 2015 Population  3.920223e+08
#                 GDP         2.530102e+12
#            2014 Population  3.842226e+08
#                 GDP         2.873600e+12
#            2013 Population  3.765043e+08
# ...                                  ...
# Zimbabwe   1962 GDP         1.117602e+09
#            1961 Population  3.876638e+06
#                 GDP         1.096647e+09
#            1960 Population  3.752390e+06
#                 GDP         1.052990e+09
#
# [22422 rows x 1 columns]

# %%
world_stats_df = world_stats_df.rename(columns={0:'Statistics'})

# %%
world_stats_df.head(n=3)
# Out:
#                               Statistics
# Country    Year
# Arab World 2015 Population  3.920223e+08
#                 GDP         2.530102e+12
#            2014 Population  3.842226e+08

# %%
wrold_stats
# Out:
#           country  year   Population           GDP
# 0      Arab World  2015  392022276.0  2.530102e+12
# 1      Arab World  2014  384222592.0  2.873600e+12
# 2      Arab World  2013  376504253.0  2.846994e+12
# 3      Arab World  2012  368802611.0  2.773270e+12
# 4      Arab World  2011  361031820.0  2.497945e+12
# ...           ...   ...          ...           ...
# 11206    Zimbabwe  1964    4279561.0  1.217138e+09
# 11207    Zimbabwe  1963    4140804.0  1.159512e+09
# 11208    Zimbabwe  1962    4006262.0  1.117602e+09
# 11209    Zimbabwe  1961    3876638.0  1.096647e+09
# 11210    Zimbabwe  1960    3752390.0  1.052990e+09
#
# [11211 rows x 4 columns]

# %%
world_stats_df
# Out:
#                               Statistics
# Country    Year
# Arab World 2015 Population  3.920223e+08
#                 GDP         2.530102e+12
#            2014 Population  3.842226e+08
#                 GDP         2.873600e+12
#            2013 Population  3.765043e+08
# ...                                  ...
# Zimbabwe   1962 GDP         1.117602e+09
#            1961 Population  3.876638e+06
#                 GDP         1.096647e+09
#            1960 Population  3.752390e+06
#                 GDP         1.052990e+09
#
# [22422 rows x 1 columns]

# %%
world_stats_df.unstack()
# Out:
#                   Statistics
#                   Population           GDP
# Country     Year
# Afghanistan 1960   8994793.0  5.377778e+08
#             1961   9164945.0  5.488889e+08
#             1962   9343772.0  5.466667e+08
#             1963   9531555.0  7.511112e+08
#             1964   9728645.0  8.000000e+08
# ...                      ...           ...
# Zimbabwe    2011  14255592.0  1.095623e+10
#             2012  14565482.0  1.239272e+10
#             2013  14898092.0  1.349023e+10
#             2014  15245855.0  1.419691e+10
#             2015  15602751.0  1.389294e+10
#
# [11211 rows x 2 columns]
