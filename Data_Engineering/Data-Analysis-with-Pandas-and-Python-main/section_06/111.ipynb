# %% [markdown]
# # Retrieve Rows by Index label with .loc[] Accessor

# %%
import pandas as pd
james_bond = pd.read_csv('jamesbond.csv', index_col = 'Film')
james_bond = james_bond.sort_index()
james_bond.head(n=2)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3

# %%
james_bond.loc['Casino Royale']
# Out:
#                Year         Actor         Director  Box Office  Budget  \
# Film
# Casino Royale  2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale  1967   David Niven       Ken Hughes       315.0    85.0
#
#                Bond Actor Salary
# Film
# Casino Royale                3.3
# Casino Royale                NaN

# %%
james_bond.loc['Goldfinger']
# Out:
# Year                         1964
# Actor                Sean Connery
# Director             Guy Hamilton
# Box Office                  820.4
# Budget                       18.6
# Bond Actor Salary             3.2
# Name: Goldfinger, dtype: object

# %%
james_bond.loc['GoldenEye']
# Out:
# Year                            1995
# Actor                 Pierce Brosnan
# Director             Martin Campbell
# Box Office                     518.5
# Budget                          76.9
# Bond Actor Salary                5.1
# Name: GoldenEye, dtype: object

# %%
james_bond.loc['Casino Royale']
# Out:
#                Year         Actor         Director  Box Office  Budget  \
# Film
# Casino Royale  2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale  1967   David Niven       Ken Hughes       315.0    85.0
#
#                Bond Actor Salary
# Film
# Casino Royale                3.3
# Casino Royale                NaN

# %%
james_bond.loc['Diamonds Are Forever':'From Russia with Love']
# Out:
#                        Year           Actor       Director  Box Office  \
# Film
# Diamonds Are Forever   1971    Sean Connery   Guy Hamilton       442.5
# Die Another Day        2002  Pierce Brosnan   Lee Tamahori       465.4
# Dr. No                 1962    Sean Connery  Terence Young       448.8
# For Your Eyes Only     1981     Roger Moore      John Glen       449.4
# From Russia with Love  1963    Sean Connery  Terence Young       543.8
#
#                        Budget  Bond Actor Salary
# Film
# Diamonds Are Forever     34.7                5.8
# Die Another Day         154.2               17.9
# Dr. No                    7.0                0.6
# For Your Eyes Only       60.2                NaN
# From Russia with Love    12.6                1.6

# %%
james_bond.loc['Diamonds Are Forever':'From Russia with Love':2]
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Diamonds Are Forever   1971  Sean Connery   Guy Hamilton       442.5    34.7
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
#
#                        Bond Actor Salary
# Film
# Diamonds Are Forever                 5.8
# Dr. No                               0.6
# From Russia with Love                1.6

# %%
james_bond.loc['GoldenEye':]
# Out:
#                                  Year           Actor            Director  \
# Film
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# Never Say Never Again            1983    Sean Connery      Irvin Kershner
# Octopussy                        1983     Roger Moore           John Glen
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Quantum of Solace                2008    Daniel Craig        Marc Forster
# Skyfall                          2012    Daniel Craig          Sam Mendes
# Spectre                          2015    Daniel Craig          Sam Mendes
# The Living Daylights             1987  Timothy Dalton           John Glen
# ...

# %%
james_bond.loc[:'Skyfall']
# Out:
#                                  Year           Actor         Director  \
# Film
# A View to a Kill                 1985     Roger Moore        John Glen
# Casino Royale                    2006    Daniel Craig  Martin Campbell
# Casino Royale                    1967     David Niven       Ken Hughes
# Diamonds Are Forever             1971    Sean Connery     Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan     Lee Tamahori
# Dr. No                           1962    Sean Connery    Terence Young
# For Your Eyes Only               1981     Roger Moore        John Glen
# From Russia with Love            1963    Sean Connery    Terence Young
# GoldenEye                        1995  Pierce Brosnan  Martin Campbell
# Goldfinger                       1964    Sean Connery     Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton        John Glen
# Live and Let Die                 1973     Roger Moore     Guy Hamilton
# ...

# %%
james_bond.loc[:"On Her Majesty's Secret Service":3]
# Out:
#                                  Year           Actor       Director  \
# Film
# A View to a Kill                 1985     Roger Moore      John Glen
# Diamonds Are Forever             1971    Sean Connery   Guy Hamilton
# For Your Eyes Only               1981     Roger Moore      John Glen
# Goldfinger                       1964    Sean Connery   Guy Hamilton
# Moonraker                        1979     Roger Moore  Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# A View to a Kill                      275.2    54.5                9.1
# Diamonds Are Forever                  442.5    34.7                5.8
# For Your Eyes Only                    449.4    60.2                NaN
# Goldfinger                            820.4    18.6                3.2
# Moonraker                             535.0    91.5                NaN
# ...

# %%
james_bond.loc[['Die Another Day', 'Octopussy']]
# Out:
#                  Year           Actor      Director  Box Office  Budget  \
# Film
# Die Another Day  2002  Pierce Brosnan  Lee Tamahori       465.4   154.2
# Octopussy        1983     Roger Moore     John Glen       373.8    53.9
#
#                  Bond Actor Salary
# Film
# Die Another Day               17.9
# Octopussy                      7.8

# %%
james_bond.loc[['Octopussy', 'Die Another Day']]
# Out:
#                  Year           Actor      Director  Box Office  Budget  \
# Film
# Octopussy        1983     Roger Moore     John Glen       373.8    53.9
# Die Another Day  2002  Pierce Brosnan  Lee Tamahori       465.4   154.2
#
#                  Bond Actor Salary
# Film
# Octopussy                      7.8
# Die Another Day               17.9

# %%
jb_index = james_bond.index.values
bond_array = []
for bond in jb_index:
    bond_array.append(bond)
bond_array
# Out:
# ['A View to a Kill',
#  'Casino Royale',
#  'Casino Royale',
#  'Diamonds Are Forever',
#  'Die Another Day',
#  'Dr. No',
#  'For Your Eyes Only',
#  'From Russia with Love',
#  'GoldenEye',
#  'Goldfinger',
#  'Licence to Kill',
#  'Live and Let Die',
#  'Moonraker',
#  'Never Say Never Again',
#  'Octopussy',
#  "On Her Majesty's Secret Service",
#  'Quantum of Solace',
#  'Skyfall',
#  'Spectre',
#  'The Living Daylights',
#  'The Man with the Golden Gun',
#  'The Spy Who Loved Me',
#  'The World Is Not Enough',
#  'Thunderball',
#  'Tomorrow Never Dies',
#  'You Only Live Twice']

# %%
james_bond[bond_array[0]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Tom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'A View to a Kill'
#
# ...

# %%
james_bond.loc['A View to a Kill']
# Out:
# Year                        1985
# Actor                Roger Moore
# Director               John Glen
# Box Office                 275.2
# Budget                      54.5
# Bond Actor Salary            9.1
# Name: A View to a Kill, dtype: object

# %%
james_bond.loc[bond_array[0]]
# Out:
# Year                        1985
# Actor                Roger Moore
# Director               John Glen
# Box Office                 275.2
# Budget                      54.5
# Bond Actor Salary            9.1
# Name: A View to a Kill, dtype: object

# %%
james_bond.loc[bond_array]
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# ...

# %%
jb_index
# Out:
# array(['A View to a Kill', 'Casino Royale', 'Casino Royale',
#        'Diamonds Are Forever', 'Die Another Day', 'Dr. No',
#        'For Your Eyes Only', 'From Russia with Love', 'GoldenEye',
#        'Goldfinger', 'Licence to Kill', 'Live and Let Die', 'Moonraker',
#        'Never Say Never Again', 'Octopussy',
#        "On Her Majesty's Secret Service", 'Quantum of Solace', 'Skyfall',
#        'Spectre', 'The Living Daylights', 'The Man with the Golden Gun',
#        'The Spy Who Loved Me', 'The World Is Not Enough', 'Thunderball',
#        'Tomorrow Never Dies', 'You Only Live Twice'], dtype=object)

# %%
james_bond.loc[jb_index]
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# ...

# %%
jb_index = james_bond.index

# %%
jb_index
# Out:
# Index(['A View to a Kill', 'Casino Royale', 'Casino Royale',
#        'Diamonds Are Forever', 'Die Another Day', 'Dr. No',
#        'For Your Eyes Only', 'From Russia with Love', 'GoldenEye',
#        'Goldfinger', 'Licence to Kill', 'Live and Let Die', 'Moonraker',
#        'Never Say Never Again', 'Octopussy', 'On Her Majesty's Secret Service',
#        'Quantum of Solace', 'Skyfall', 'Spectre', 'The Living Daylights',
#        'The Man with the Golden Gun', 'The Spy Who Loved Me',
#        'The World Is Not Enough', 'Thunderball', 'Tomorrow Never Dies',
#        'You Only Live Twice'],
#       dtype='object', name='Film')

# %%
james_bond.loc[jb_index]
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# ...

# %%
james_bond.loc[james_bond.index]
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# ...

# %%
james_bond.loc[james_bond.index[::5]]
# Out:
#                                  Year           Actor       Director  \
# Film
# A View to a Kill                 1985     Roger Moore      John Glen
# Dr. No                           1962    Sean Connery  Terence Young
# Licence to Kill                  1989  Timothy Dalton      John Glen
# On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
# The Man with the Golden Gun      1974     Roger Moore   Guy Hamilton
# You Only Live Twice              1967    Sean Connery  Lewis Gilbert
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# A View to a Kill                      275.2    54.5                9.1
# Dr. No                                448.8     7.0                0.6
# Licence to Kill                       250.9    56.7                7.9
# On Her Majesty's Secret Service       291.5    37.3                0.6
# The Man with the Golden Gun           334.0    27.7                NaN
# ...

# %%
james_bond.loc[james_bond.index[5::2]]
# Out:
#                                  Year           Actor        Director  \
# Film
# Dr. No                           1962    Sean Connery   Terence Young
# From Russia with Love            1963    Sean Connery   Terence Young
# Goldfinger                       1964    Sean Connery    Guy Hamilton
# Live and Let Die                 1973     Roger Moore    Guy Hamilton
# Never Say Never Again            1983    Sean Connery  Irvin Kershner
# On Her Majesty's Secret Service  1969  George Lazenby   Peter R. Hunt
# Skyfall                          2012    Daniel Craig      Sam Mendes
# The Living Daylights             1987  Timothy Dalton       John Glen
# The Spy Who Loved Me             1977     Roger Moore   Lewis Gilbert
# Thunderball                      1965    Sean Connery   Terence Young
# You Only Live Twice              1967    Sean Connery   Lewis Gilbert
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# ...

# %%
# 'Gold Bond'<-- not valid index
bond_array.append('Gold Bond')
james_bond.loc[bond_array]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\Tom\iCloudDrive\Nauka\Python\Pyton_files\Data-Analysis-with-Pandas-and-Python\section_06\111.ipynb Cell 27 in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/Tom/iCloudDrive/Nauka/Python/Pyton_files/Data-Analysis-with-Pandas-and-Python/section_06/111.ipynb#ch0000027?line=0'>1</a> # 'Gold Bond'<-- not valid index
#       <a href='vscode-notebook-cell:/c%3A/Users/Tom/iCloudDrive/Nauka/Python/Pyton_files/Data-Analysis-with-Pandas-and-Python/section_06/111.ipynb#ch0000027?line=1'>2</a> bond_array.append('Gold Bond')
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Tom/iCloudDrive/Nauka/Python/Pyton_files/Data-Analysis-with-Pandas-and-Python/section_06/111.ipynb#ch0000027?line=2'>3</a> james_bond.loc[bond_array]
#
# ...

# %%
'Gold Bond' in james_bond.index
# Out:
# False
