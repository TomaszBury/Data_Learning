# %% [markdown]
# # Pass a URL to the pd.read_csv Method

# %%
import pandas as pd

# %%
url = 'https://data.cityofnewyork.us/api/views/25th-nujf/rows.csv'

# %%
pd.read_csv(url)
# Out:
#        Year of Birth  Gender           Ethnicity Child's First Name  Count  \
# 0               2011  FEMALE            HISPANIC          GERALDINE     13
# 1               2011  FEMALE            HISPANIC                GIA     21
# 2               2011  FEMALE            HISPANIC             GIANNA     49
# 3               2011  FEMALE            HISPANIC            GISELLE     38
# 4               2011  FEMALE            HISPANIC              GRACE     36
# ...              ...     ...                 ...                ...    ...
# 47540           2014    MALE  WHITE NON HISPANIC             Yousef     18
# 47541           2014    MALE  WHITE NON HISPANIC            Youssef     24
# 47542           2014    MALE  WHITE NON HISPANIC              Yusuf     16
# 47543           2014    MALE  WHITE NON HISPANIC            Zachary     90
# 47544           2014    MALE  WHITE NON HISPANIC                Zev     49
#
#        Rank
# 0        75
# 1        67
# 2        42
# 3        51
# 4        53
# ...     ...
# 47540    94
# 47541    88
# 47542    96
# 47543    39
# 47544    65
#
# [47545 rows x 6 columns]

# %%
baby_names = pd.read_csv(url)

# %%
baby_names.tail()
# Out:
#        Year of Birth Gender           Ethnicity Child's First Name  Count  \
# 47540           2014   MALE  WHITE NON HISPANIC             Yousef     18
# 47541           2014   MALE  WHITE NON HISPANIC            Youssef     24
# 47542           2014   MALE  WHITE NON HISPANIC              Yusuf     16
# 47543           2014   MALE  WHITE NON HISPANIC            Zachary     90
# 47544           2014   MALE  WHITE NON HISPANIC                Zev     49
#
#        Rank
# 47540    94
# 47541    88
# 47542    96
# 47543    39
# 47544    65
